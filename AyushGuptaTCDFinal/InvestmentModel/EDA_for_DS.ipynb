# %%
pip list
# Out:
# Package                      VersionNote: you may need to restart the kernel to use updated packages.
# ---------------------------- ---------
# absl-py                      1.1.0
# WARNING: You are using pip version 21.1.2; however, version 22.1.2 is available.
# You should consider upgrading via the 'c:\users\ayush\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.
# argon2-cffi                  20.1.0
# astunparse                   1.6.3
# async-generator              1.10
# attrs                        21.2.0
# backcall                     0.2.0
# beautifulsoup4               4.10.0
# bleach                       3.3.0
# bs4                          0.0.1
# cachetools                   5.2.0
# certifi                      2021.10.8
# cffi                         1.14.5
# charset-normalizer           2.0.7
# click                        8.0.3
# colorama                     0.4.4
# cycler                       0.10.0
# ...

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
import math
# %matplotlib inline

# %%
pip install openpyxl
# Out:
# ...
# WARNING: You are using pip version 21.1.2; however, version 22.1.2 is available.
# You should consider upgrading via the 'c:\users\ayush\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
df = pd.read_excel(r'C:\Users\ayush\Desktop\Hubli Project\InvestmentModel\IndianStartupsKaggle.xlsx')
OriginalData = df
print (OriginalData)
# Out:
#       Sr No      Date dd/mm/yyyy                  Startup Name  \
# 0         1  2020-01-09 00:00:00                        BYJU’S
# 1         2  2020-01-13 00:00:00                        Shuttl
# 2         3  2020-01-09 00:00:00                     Mamaearth
# 3         4  2020-01-02 00:00:00  https://www.wealthbucket.in/
# 4         5  2020-01-02 00:00:00                        Fashor
# ...     ...                  ...                           ...
# 3039   3040  2015-01-29 00:00:00                    Printvenue
# 3040   3041  2015-01-29 00:00:00                      Graphene
# 3041   3042  2015-01-30 00:00:00                Mad Street Den
# 3042   3043  2015-01-30 00:00:00                     Simplotel
# 3043   3044  2015-01-31 00:00:00              couponmachine.in
#
#         Industry Vertical                            SubVertical  \
# 0                  E-Tech                             E-learning
# 1          Transportation              App based shuttle service
# ...

# %%
df.head()
# Out:
#    Sr No      Date dd/mm/yyyy                  Startup Name  \
# 0      1  2020-01-09 00:00:00                        BYJU’S
# 1      2  2020-01-13 00:00:00                        Shuttl
# 2      3  2020-01-09 00:00:00                     Mamaearth
# 3      4  2020-01-02 00:00:00  https://www.wealthbucket.in/
# 4      5  2020-01-02 00:00:00                        Fashor
#
#      Industry Vertical                            SubVertical City  Location  \
# 0               E-Tech                             E-learning      Bengaluru
# 1       Transportation              App based shuttle service        Gurgaon
# 2           E-commerce  Retailer of baby and toddler products      Bengaluru
# 3              FinTech                      Online Investment      New Delhi
# 4  Fashion and Apparel            Embroiled Clothes For Women         Mumbai
#
#               Investors Name       InvestmentnType Amount in USD Remarks
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3044 entries, 0 to 3043
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Sr No              3044 non-null   int64
#  1   Date dd/mm/yyyy    3044 non-null   object
#  2   Startup Name       3044 non-null   object
#  3   Industry Vertical  2873 non-null   object
#  4   SubVertical        2108 non-null   object
#  5   City  Location     2864 non-null   object
#  6   Investors Name     3020 non-null   object
#  7   InvestmentnType    3040 non-null   object
#  8   Amount in USD      2084 non-null   object
#  9   Remarks            419 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 237.9+ KB

# %%
OriginalData['InvestmentnType'].value_counts()
# Out:
# Private Equity                 1356
# Seed Funding                   1355
# Seed/ Angel Funding              60
# Seed / Angel Funding             47
# Seed\\nFunding                   30
# Debt Funding                     25
# Series A                         24
# Seed/Angel Funding               23
# Series B                         20
# Series C                         14
# Series D                         12
# Angel / Seed Funding              8
# Seed Round                        7
# Pre-Series A                      4
# Private Equity Round              4
# Seed                              4
# Seed / Angle Funding              3
# pre-Series A                      2
# Venture Round                     2
# Equity                            2
# Corporate Round                   2
# Series E                          2
# Series F                          2
# Private                           1
# Debt-Funding                      1
# Term Loan                         1
# ...

# %% [markdown]
# # <font color = 'blue'>Transforming the data to Categorize different stages together(Data Cleaning)</font>

# %%
OriginalInvestmentLength = len(OriginalData['InvestmentnType'].unique())
print(OriginalInvestmentLength)
# Out:
# 55

# %%
df['InvestmentnType'] = df['InvestmentnType'].replace('Seed Round',"Seed Funding")

# %%
InvestmentLength = len(df['InvestmentnType'].unique())
print(InvestmentLength)
# Out:
# 55

# %%
df['InvestmentnType'] = df['InvestmentnType'].replace('Seed\\nFunding',"Seed Funding", regex=True)

# %%
df['InvestmentnType'] = df['InvestmentnType'].replace('Seed/ Angel Funding',"Seed Angel Funding", regex = True)

# %%
df['InvestmentnType'].value_counts()
# Out:
# Seed Funding                   1362
# Private Equity                 1356
# Seed Angel Funding               60
# Seed / Angel Funding             47
# Seed\\nFunding                   30
# Debt Funding                     25
# Series A                         24
# Seed/Angel Funding               23
# Series B                         20
# Series C                         14
# Series D                         12
# Angel / Seed Funding              8
# Pre-Series A                      4
# Private Equity Round              4
# Seed                              4
# Seed / Angle Funding              3
# pre-Series A                      2
# Venture Round                     2
# Equity                            2
# Corporate Round                   2
# Series E                          2
# Series F                          2
# Private                           1
# Debt-Funding                      1
# Term Loan                         1
# Seed funding                      1
# ...

# %%
df.value_counts()
# Out:
# Series([], dtype: int64)

# %%
InvestmentLength = len(df['InvestmentnType'].unique())
print(InvestmentLength)
# Out:
# 55

# %%
InvestmentLength = len(df['InvestmentnType'].unique())
print(InvestmentLength)
# Out:
# 55

# %%
df['InvestmentnType'].value_counts()
# Out:
# Seed Funding                   1362
# Private Equity                 1356
# Seed Angel Funding               60
# Seed / Angel Funding             47
# Seed\\nFunding                   30
# Debt Funding                     25
# Series A                         24
# Seed/Angel Funding               23
# Series B                         20
# Series C                         14
# Series D                         12
# Angel / Seed Funding              8
# Pre-Series A                      4
# Private Equity Round              4
# Seed                              4
# Seed / Angle Funding              3
# pre-Series A                      2
# Venture Round                     2
# Equity                            2
# Corporate Round                   2
# Series E                          2
# Series F                          2
# Private                           1
# Debt-Funding                      1
# Term Loan                         1
# Seed funding                      1
# ...

# %%
df['InvestmentnType'] = df['InvestmentnType'].replace('Seed//nFunding',"Seed Funding", regex = True)

# %%
df['InvestmentnType'] = df['InvestmentnType'].replace('Seed / Angel Funding',"Seed Angel Funding", regex = True)

# %%
df['InvestmentnType'] = df['InvestmentnType'].replace('Private//nEquity',"Private Equity", regex = True)

# %%
df['InvestmentnType'].value_counts()
# Out:
# Seed Funding                   1362
# Private Equity                 1356
# Seed Angel Funding              107
# Seed\\nFunding                   30
# Debt Funding                     25
# Series A                         24
# Seed/Angel Funding               23
# Series B                         20
# Series C                         14
# Series D                         12
# Angel / Seed Funding              8
# Pre-Series A                      4
# Seed                              4
# Private Equity Round              4
# Seed / Angle Funding              3
# Corporate Round                   2
# Series F                          2
# Equity                            2
# pre-Series A                      2
# Venture Round                     2
# Series E                          2
# Series B (Extension)              1
# Equity Based Funding              1
# Private Funding                   1
# Mezzanine                         1
# Structured Debt                   1
# ...

# %%
df['InvestmentnType'].value_counts()
# Out:
# Seed Funding                   1362
# Private Equity                 1356
# Seed Angel Funding              107
# Seed\\nFunding                   30
# Debt Funding                     25
# Series A                         24
# Seed/Angel Funding               23
# Series B                         20
# Series C                         14
# Series D                         12
# Angel / Seed Funding              8
# Pre-Series A                      4
# Seed                              4
# Private Equity Round              4
# Seed / Angle Funding              3
# Corporate Round                   2
# Series F                          2
# Equity                            2
# pre-Series A                      2
# Venture Round                     2
# Series E                          2
# Series B (Extension)              1
# Equity Based Funding              1
# Private Funding                   1
# Mezzanine                         1
# Structured Debt                   1
# ...

# %%
df['InvestmentnType'].count()
# Out:
# 3040

# %% [markdown]
# ## Made changes in Excel
# - Exported to excel
# - imported again from excel file and then checked

# %%
writer = pd.ExcelWriter('IndianStartupPythonTry.xlsx')

df.to_excel("IndianStartupPythonTry.xlsx")

New_df = pd.read_excel(r'C:\Users\ayush\Desktop\Hubli Project\InvestmentModel\PythonDataBook.xlsx')
NewOriginalData = New_df
print (NewOriginalData)
# Out:
#       Unnamed: 0  Sr No      Date dd/mm/yyyy     Startup Name  \
# 0             34     35  2019-10-21 00:00:00  The Man Company
# 1             20     21  2019-11-17 00:00:00     Burger Singh
# 2             58     59  2019-08-19 00:00:00   Mishry Reviews
# 3             89     90  2019-05-06 00:00:00     Ola Electric
# 4             91     92  2019-05-05 00:00:00       StyleDotMe
# ...          ...    ...                  ...              ...
# 3039        3027   3028  2015-05-21 00:00:00             Knit
# 3040        3030   3031  2015-01-22 00:00:00        Freshmonk
# 3041        3031   3032  2015-01-22 00:00:00  Englishleap.com
# 3042        3035   3036  2015-01-24 00:00:00         Impartus
# 3043        3042   3043  2015-01-30 00:00:00        Simplotel
#
#       Industry Vertical           SubVertical City  Location  \
# 0        Consumer Goods   Beauty and Grooming        Gurgaon
# 1     Food and Beverage   Indian Burger Brand        Gurgaon
# ...

# %%
New_df['InvestmentnType'].value_counts()
# Out:
# Seed Funding                   1392
# Private Equity                 1356
# Seed Angel Funding              138
# Debt Funding                     25
# Series A                         24
# Series B                         20
# Series C                         14
# Series D                         12
# Private Equity Round              4
# Seed                              4
# Pre-Series A                      4
# Seed / Angle Funding              3
# Series F                          2
# Equity                            2
# Series E                          2
# Corporate Round                   2
# pre-Series A                      2
# Venture Round                     2
# Series J                          1
# Single Venture                    1
# Debt                              1
# Mezzanine                         1
# Angel                             1
# Private\\nEquity                  1
# Private                           1
# PrivateEquity                     1
# ...

# %%
New_df['InvestmentnType'] = New_df['InvestmentnType'].replace('Seed / Angle Funding', 'Seed Angel Funding', regex = True)

# %%
New_df['InvestmentnType'].value_counts()
# Out:
# Seed Funding                   1392
# Private Equity                 1356
# Seed Angel Funding              141
# Debt Funding                     25
# Series A                         24
# Series B                         20
# Series C                         14
# Series D                         12
# Seed                              4
# Private Equity Round              4
# Pre-Series A                      4
# Corporate Round                   2
# Series F                          2
# Equity                            2
# Series E                          2
# Venture Round                     2
# pre-Series A                      2
# Private\\nEquity                  1
# Single Venture                    1
# Mezzanine                         1
# Debt                              1
# Series J                          1
# Angel                             1
# Private                           1
# PrivateEquity                     1
# Private Funding                   1
# ...

# %%
New_df['InvestmentnType'].nunique()
# Out:
# 49

# %%
New_df
# Out:
#       Unnamed: 0  Sr No      Date dd/mm/yyyy     Startup Name  \
# 0             34     35  2019-10-21 00:00:00  The Man Company
# 1             20     21  2019-11-17 00:00:00     Burger Singh
# 2             58     59  2019-08-19 00:00:00   Mishry Reviews
# 3             89     90  2019-05-06 00:00:00     Ola Electric
# 4             91     92  2019-05-05 00:00:00       StyleDotMe
# ...          ...    ...                  ...              ...
# 3039        3027   3028  2015-05-21 00:00:00             Knit
# 3040        3030   3031  2015-01-22 00:00:00        Freshmonk
# 3041        3031   3032  2015-01-22 00:00:00  Englishleap.com
# 3042        3035   3036  2015-01-24 00:00:00         Impartus
# 3043        3042   3043  2015-01-30 00:00:00        Simplotel
#
#       Industry Vertical           SubVertical City  Location  \
# 0        Consumer Goods   Beauty and Grooming        Gurgaon
# 1     Food and Beverage   Indian Burger Brand        Gurgaon
# ...

# %% [markdown]
# ## Exploratory Data Analysis

# %%
sns.countplot(New_df['Amount in USD'].head(20))
# Out:
# c:\users\ayush\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Amount in USD', ylabel='count'>

# %%
GroupedVertical = New_df.groupby(['Industry Vertical'])

# %%
type(New_df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(GroupedVertical)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
GroupedVertical['Amount in USD']
# Out:
# 0       20,00,00,000
# 1          80,48,394
# 2        1,83,58,860
# 3          30,00,000
# 4          18,00,000
#             ...
# 2873       55,00,000
# 2874        1,20,000
# 2875     1,50,00,000
# 2876             NaN
# 2877       10,00,000
# Name: Amount in USD, Length: 992, dtype: object

# %%
sns.countplot(x ='Industry Vertical', data = New_df,palette = 'viridis')
# Out:
# <AxesSubplot:xlabel='Industry Vertical', ylabel='count'>

# %%
from wordcloud import WordCloud

# %%
WordDF = New_df['Industry Vertical'].value_counts().to_dict()
wc = WordCloud(background_color = 'black').generate_from_frequencies(WordDF)

plt.figure(figsize=[10,10])
plt.imshow(wc)
plt.axis('off')
plt.show()

# %%
New_df['Industry Vertical'].unique()
# Out:
# array(['E-Tech', 'Transportation', 'E-commerce', 'FinTech',
#        'Fashion and Apparel', 'Logistics', 'Hospitality', 'Technology',
#        'E-Commerce', 'Aerospace', 'B2B-focused foodtech startup',
#        'Finance', 'Video', 'Gaming', 'Software', 'Health and wellness',
#        'Education', 'Food and Beverage', 'Health and Wellness',
#        'B2B Marketing', 'Video Games', 'SaaS', 'Last Mile Transportation',
#        'Healthcare', 'Customer Service', 'B2B', 'Consumer Goods',
#        'Advertising, Marketing', 'IoT', 'Information Technology',
#        'Consumer Technology', 'Accounting', 'Retail',
#        'Customer Service Platform', 'Automotive', 'EdTech', 'Services',
#        'Compliance', 'Transport', 'Artificial Intelligence', 'Tech',
#        'Health Care', 'Luxury Label', 'Waste Management Service',
#        'Deep-Tech', 'Agriculture', 'Energy', 'Digital Media', 'Saas',
#        'Automobile', 'Agtech', 'Social Media', 'Fintech', 'Edtech', 'AI',
# ...

# %%
New_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3044 entries, 0 to 3043
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         3044 non-null   int64
#  1   Sr No              3044 non-null   int64
#  2   Date dd/mm/yyyy    3044 non-null   object
#  3   Startup Name       3044 non-null   object
#  4   Industry Vertical  2873 non-null   object
#  5   SubVertical        2108 non-null   object
#  6   City  Location     2864 non-null   object
#  7   Investors Name     3020 non-null   object
#  8   InvestmentnType    3040 non-null   object
#  9   Amount in USD      2084 non-null   object
#  10  Remarks            419 non-null    object
# dtypes: int64(2), object(9)
# memory usage: 261.7+ KB

# %%
Investment_null_data = New_df[New_df['Amount in USD'].isnull()]
City_null_data = New_df[New_df['City  Location'].isnull()]
SubVertical_null_data = New_df[New_df['SubVertical'].isnull()]
Type_null_data = New_df[New_df['InvestmentnType'].isnull()]
Vertical_null_data = New_df[New_df['Industry Vertical'].isnull()]

# %%
Investment_null_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 960 entries, 144 to 3042
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         960 non-null    int64
#  1   Sr No              960 non-null    int64
#  2   Date dd/mm/yyyy    960 non-null    object
#  3   Startup Name       960 non-null    object
#  4   Industry Vertical  920 non-null    object
#  5   SubVertical        682 non-null    object
#  6   City  Location     915 non-null    object
#  7   Investors Name     956 non-null    object
#  8   InvestmentnType    959 non-null    object
#  9   Amount in USD      0 non-null      object
#  10  Remarks            78 non-null     object
# dtypes: int64(2), object(9)
# memory usage: 90.0+ KB

# %%
City_null_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 180 entries, 338 to 3043
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         180 non-null    int64
#  1   Sr No              180 non-null    int64
#  2   Date dd/mm/yyyy    180 non-null    object
#  3   Startup Name       180 non-null    object
#  4   Industry Vertical  9 non-null      object
#  5   SubVertical        6 non-null      object
#  6   City  Location     0 non-null      object
#  7   Investors Name     180 non-null    object
#  8   InvestmentnType    180 non-null    object
#  9   Amount in USD      135 non-null    object
#  10  Remarks            70 non-null     object
# dtypes: int64(2), object(9)
# memory usage: 16.9+ KB

# %%
SubVertical_null_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 936 entries, 2108 to 3043
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         936 non-null    int64
#  1   Sr No              936 non-null    int64
#  2   Date dd/mm/yyyy    936 non-null    object
#  3   Startup Name       936 non-null    object
#  4   Industry Vertical  765 non-null    object
#  5   SubVertical        0 non-null      object
#  6   City  Location     762 non-null    object
#  7   Investors Name     930 non-null    object
#  8   InvestmentnType    936 non-null    object
#  9   Amount in USD      658 non-null    object
#  10  Remarks            419 non-null    object
# dtypes: int64(2), object(9)
# memory usage: 87.8+ KB

# %%
Type_null_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4 entries, 30 to 1562
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         4 non-null      int64
#  1   Sr No              4 non-null      int64
#  2   Date dd/mm/yyyy    4 non-null      object
#  3   Startup Name       4 non-null      object
#  4   Industry Vertical  4 non-null      object
#  5   SubVertical        4 non-null      object
#  6   City  Location     4 non-null      object
#  7   Investors Name     4 non-null      object
#  8   InvestmentnType    0 non-null      object
#  9   Amount in USD      3 non-null      object
#  10  Remarks            0 non-null      object
# dtypes: int64(2), object(9)
# memory usage: 384.0+ bytes

# %%
Vertical_null_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 171 entries, 2873 to 3043
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         171 non-null    int64
#  1   Sr No              171 non-null    int64
#  2   Date dd/mm/yyyy    171 non-null    object
#  3   Startup Name       171 non-null    object
#  4   Industry Vertical  0 non-null      object
#  5   SubVertical        0 non-null      object
#  6   City  Location     0 non-null      object
#  7   Investors Name     171 non-null    object
#  8   InvestmentnType    171 non-null    object
#  9   Amount in USD      131 non-null    object
#  10  Remarks            68 non-null     object
# dtypes: int64(2), object(9)
# memory usage: 16.0+ KB

# %%
New_df['Amount in USD'].head(20)
# Out:
# 0         unknown
# 1     undisclosed
# 2     Undisclosed
# 3     undisclosed
# 4     undisclosed
# 5     Undisclosed
# 6     Undisclosed
# 7       97,00,000
# 8       96,00,000
# 9       95,00,000
# 10      95,00,000
# 11      92,00,000
# 12      92,00,000
# 13      92,00,000
# 14      91,00,000
# 15      90,00,000
# 16      90,00,000
# 17      90,00,000
# 18      90,00,000
# 19      90,00,000
# Name: Amount in USD, dtype: object

# %%
New_df['RupeeValue'] = New_df['Amount in USD']*78.96
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\users\ayush\appdata\local\programs\python\python39\lib\site-packages\pandas\core\ops\array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     165     try:
# --> 166         result = func(left, right)
#     167     except TypeError:
#
# c:\users\ayush\appdata\local\programs\python\python39\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, a, b, use_numexpr)
#     238             # error: "None" not callable
# --> 239             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240     return _evaluate_standard(op, op_str, a, b)
#
# c:\users\ayush\appdata\local\programs\python\python39\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b)
#      68         _store_test_result(False)
# ---> 69     return op(a, b)
#      70
#
# ...

# %%
CompleteUSD = New_df['Amount in USD'].dropna()

# %%
ListCompleteUSD = CompleteUSD.to_list()

# %%
type(ListCompleteUSD[0])
# Out:
# str

# %%
print([x for x in range(1,10)])
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
try1 = [x for x in range(1,10)]

# %%
[i for i in try1 if i>5]
# Out:
# [6, 7, 8, 9]

# %%
type(try1[0])
# Out:
# int

# %%
[x for x in ListCompleteUSD if (x>10000 & x<150000)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-420-6e896b8ec65a> in <module>
# ----> 1 [x for x in ListCompleteUSD if (x>10000 & x<150000)]
#
# <ipython-input-420-6e896b8ec65a> in <listcomp>(.0)
# ----> 1 [x for x in ListCompleteUSD if (x>10000 & x<150000)]
#
# TypeError: unsupported operand type(s) for &: 'int' and 'str'

# %% [markdown]
# ### run this command 3 times

# %%
ListCompleteUSD.remove('14,342,000+')

# %%
Required_list = pd.DataFrame(data=[x for x in CompleteUSD])

# %%
ListCompleteUSD.remove('unknown')

# %%
TruncUSD = []
for x in ListCompleteUSD:
    TruncUSD.append(str(x).split('.')[0])

# %%
type(TruncUSD[0])
# Out:
# str

# %%
from babel.numbers import parse_decimal , parse_number

# %%
try1 = [float(parse_decimal(TruncUSD[:3],locale ='es_MX'))]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-314-836038c858c5> in <module>
# ----> 1 try1 = [float(parse_decimal(TruncUSD[:3],locale ='es_MX'))]
#
# c:\users\ayush\appdata\local\programs\python\python39\lib\site-packages\babel\numbers.py in parse_decimal(string, locale, strict)
#     742
#     743     try:
# --> 744         parsed = decimal.Decimal(string.replace(group_symbol, '')
#     745                                        .replace(decimal_symbol, '.'))
#     746     except decimal.InvalidOperation:
#
# AttributeError: 'list' object has no attribute 'replace'

# %%
try1
# Out:
# 8048394.0

# %%
IntListCompleteUSD = [int(x.replace(',','')) for x in TruncUSD]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-249-90e2030f698d> in <module>
# ----> 1 IntListCompleteUSD = [int(x.replace(',','')) for x in TruncUSD]
#
# <ipython-input-249-90e2030f698d> in <listcomp>(.0)
# ----> 1 IntListCompleteUSD = [int(x.replace(',','')) for x in TruncUSD]
#
# ValueError: invalid literal for int() with base 10: '\\\\xc2\\\\xa020000000'

# %%
ListCompleteUSD.remove('\\\\xc2\\\\xa020000000')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-250-d048ef145cb6> in <module>
# ----> 1 ListCompleteUSD.remove('\\\\xc2\\\\xa020000000')
#
# ValueError: list.remove(x): x not in list

# %%
type(ListCompleteUSD[0])
# Out:
# str

# %%
ListCompleteUSD.count('14,342,000+')
# Out:
# 1

# %%
ListCompleteUSD
# Out:
# ['20,00,00,000',
#  '80,48,394',
#  '1,83,58,860',
#  '30,00,000',
#  '18,00,000',
#  '90,00,000',
#  '15,00,00,000',
#  '60,00,000',
#  '7,00,00,000',
#  '5,00,00,000',
#  '2,00,00,000',
#  '1,20,00,000',
#  '3,00,00,000',
#  '59,00,000',
#  '20,00,000',
#  '5,00,00,000',
#  '23,10,00,000',
#  '15,00,00,000',
#  '4,86,000',
#  '15,00,000',
#  '1,20,00,000',
#  '2,60,00,000',
#  '1,74,11,265',
#  '13,00,000',
#  '13,50,00,000',
#  '3,00,000',
#  '22,00,00,000',
#  '1,58,00,000',
#  '28,30,00,000',
#  '20,00,00,000',
#  '1,00,00,00,000',
#  '4,50,00,000',
#  '58,50,00,000',
#  '45,00,000',
#  '33,00,000',
#  '60,00,000',
#  '50,00,000',
#  '1,80,00,000',
#  '10,00,000',
#  '1,00,00,000',
#  '45,00,00,000',
#  '50,00,000',
#  '2,00,00,000',
#  '50,00,000',
#  '16,00,000',
#  '14,00,00,000',
#  '3,80,80,000',
#  '12,50,00,000',
#  '1,10,00,000',
#  '5,10,00,000',
#  '3,70,00,000',
#  '5,00,000',
#  '11,00,00,000',
#  '1,50,00,000',
#  '65,90,000',
#  '10,00,000',
#  '7,00,00,000',
# ...

# %%
DataFrameUSD = pd.DataFrame(TruncUSD)

# %%
DataFrameUSD
# Out:
#                  0
# 0     20,00,00,000
# 1        80,48,394
# 2      1,83,58,860
# 3        30,00,000
# 4        18,00,000
# ...            ...
# 2071     25,00,000
# 2072     45,00,000
# 2073      8,25,000
# 2074     15,00,000
# 2075      1,40,000
#
# [2076 rows x 1 columns]

# %%
TruncUSD[2015]
# Out:
# '1,65,00,000'

# %%
ListCompleteUSD
# Out:
# ['20,00,00,000',
#  '80,48,394',
#  '1,83,58,860',
#  '30,00,000',
#  '18,00,000',
#  '90,00,000',
#  '15,00,00,000',
#  '60,00,000',
#  '7,00,00,000',
#  '5,00,00,000',
#  '2,00,00,000',
#  '1,20,00,000',
#  '3,00,00,000',
#  '59,00,000',
#  '20,00,000',
#  '5,00,00,000',
#  '23,10,00,000',
#  '15,00,00,000',
#  '4,86,000',
#  '15,00,000',
#  '1,20,00,000',
#  '2,60,00,000',
#  '1,74,11,265',
#  '13,00,000',
#  '13,50,00,000',
#  '3,00,000',
#  '22,00,00,000',
#  '1,58,00,000',
#  '28,30,00,000',
#  '20,00,00,000',
#  '1,00,00,00,000',
#  '4,50,00,000',
#  '58,50,00,000',
#  '45,00,000',
#  '33,00,000',
#  '60,00,000',
#  '50,00,000',
#  '1,80,00,000',
#  '10,00,000',
#  '1,00,00,000',
#  '45,00,00,000',
#  '50,00,000',
#  '2,00,00,000',
#  '50,00,000',
#  '16,00,000',
#  '14,00,00,000',
#  '3,80,80,000',
#  '12,50,00,000',
#  '1,10,00,000',
#  '5,10,00,000',
#  '3,70,00,000',
#  '5,00,000',
#  '11,00,00,000',
#  '1,50,00,000',
#  '65,90,000',
#  '10,00,000',
#  '7,00,00,000',
# ...

# %%
writer = pd.ExcelWriter('USD_datapoint.xlsx')

DataFrameUSD.to_excel("USD_datapoint.xlsx")

ReadUS_DataFrame = pd.read_excel(r'C:\Users\ayush\Desktop\Hubli Project\InvestmentModel\USD_datapoint.xlsx')

# %%
ReadUSD = pd.read_excel(r'C:\Users\ayush\Desktop\Hubli Project\InvestmentModel\DoesItworkUSD.xlsx')

# %%
ReadUSD
# Out:
#       Unnamed: 0             0
# 0              0  20,00,00,000
# 1              1     80,48,394
# 2              2   1,83,58,860
# 3              3     30,00,000
# 4              4     18,00,000
# ...          ...           ...
# 2071        2071     25,00,000
# 2072        2072     45,00,000
# 2073        2073      8,25,000
# 2074        2074     15,00,000
# 2075        2075      1,40,000
#
# [2076 rows x 2 columns]

# %%
IntCompleteUSD = [x.replace(',','') for x in ReadUSDColumn]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-303-3539c7456ec8> in <module>
# ----> 1 IntCompleteUSD = [x.replace(',','') for x in ReadUSDColumn]
#
# <ipython-input-303-3539c7456ec8> in <listcomp>(.0)
# ----> 1 IntCompleteUSD = [x.replace(',','') for x in ReadUSDColumn]
#
# AttributeError: 'float' object has no attribute 'replace'

# %%
ReadUSDColumn = ReadUSD[0].to_list()

# %%
ReadUSDColumn
# Out:
# ['20,00,00,000',
#  '80,48,394',
#  '1,83,58,860',
#  '30,00,000',
#  '18,00,000',
#  '90,00,000',
#  '15,00,00,000',
#  '60,00,000',
#  '7,00,00,000',
#  '5,00,00,000',
#  '2,00,00,000',
#  '1,20,00,000',
#  '3,00,00,000',
#  '59,00,000',
#  '20,00,000',
#  '5,00,00,000',
#  '23,10,00,000',
#  '15,00,00,000',
#  '4,86,000',
#  '15,00,000',
#  '1,20,00,000',
#  '2,60,00,000',
#  '1,74,11,265',
#  '13,00,000',
#  '13,50,00,000',
#  '3,00,000',
#  '22,00,00,000',
#  '1,58,00,000',
#  '28,30,00,000',
#  '20,00,00,000',
#  '1,00,00,00,000',
#  '4,50,00,000',
#  '58,50,00,000',
#  '45,00,000',
#  '33,00,000',
#  '60,00,000',
#  '50,00,000',
#  '1,80,00,000',
#  '10,00,000',
#  '1,00,00,000',
#  '45,00,00,000',
#  '50,00,000',
#  '2,00,00,000',
#  '50,00,000',
#  '16,00,000',
#  '14,00,00,000',
#  '3,80,80,000',
#  '12,50,00,000',
#  '1,10,00,000',
#  '5,10,00,000',
#  '3,70,00,000',
#  '5,00,000',
#  '11,00,00,000',
#  '1,50,00,000',
#  '65,90,000',
#  '10,00,000',
#  '7,00,00,000',
# ...

# %%
type(ReadUSDColumn[0])
# Out:
# str

# %%
ReadUSD[0].between(10000,150000,inclusive = True)

# %%
try1 = int(parse_decimal(ReadUSDColumn[3],locale ='es_MX'))

# %%
type(try1)
# Out:
# int

# %%
ReadUSD = pd.read_excel(r'C:\Users\ayush\Desktop\Hubli Project\InvestmentModel\DoesItWorkUSD.xlsx')

# %%
ReadUSD.dropna(inplace = True)

# %%
ReadUSD
# Out:
#       Unnamed: 0          0
# 0              0  200000000
# 1              1    8048394
# 2              2   18358860
# 3              3    3000000
# 4              4    1800000
# ...          ...        ...
# 2071        2071    2500000
# 2072        2072    4500000
# 2073        2073     825000
# 2074        2074    1500000
# 2075        2075     140000
#
# [2065 rows x 2 columns]

# %%
from collections import Counter

type_counts = Counter(type(x) for x in ReadUSD[0])

print(type_counts)
# Out:
# Counter({<class 'int'>: 2060, <class 'str'>: 5})

# %%
ReadUSD[0].between(10000,1500000,inclusive = False)
# Out:
# <ipython-input-356-f24de91bbcef>:1: FutureWarning: Boolean inputs to the `inclusive` argument are deprecated infavour of `both` or `neither`.
#   ReadUSD[0].between(10000,1500000,inclusive = False)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-356-f24de91bbcef> in <module>
# ----> 1 ReadUSD[0].between(10000,1500000,inclusive = False)
#
# c:\users\ayush\appdata\local\programs\python\python39\lib\site-packages\pandas\core\series.py in between(self, left, right, inclusive)
#    5117             rmask = self <= right
#    5118         elif inclusive == "neither":
# -> 5119             lmask = self > left
#    5120             rmask = self < right
#    5121         else:
#
# c:\users\ayush\appdata\local\programs\python\python39\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ...

# %%
for x in ReadUSD[0]:
    if isinstance(x, str):
        print(x)
# Out:
# 3,000,00
# 13,000,00
# 1,000,000,
# 46,000,00
# 11,000,00

# %%
ReadUSD.replace(to_replace = '3,000,00', value = 300000)
# Out:
#       Unnamed: 0          0
# 0              0  200000000
# 1              1    8048394
# 2              2   18358860
# 3              3    3000000
# 4              4    1800000
# ...          ...        ...
# 2071        2071    2500000
# 2072        2072    4500000
# 2073        2073     825000
# 2074        2074    1500000
# 2075        2075     140000
#
# [2065 rows x 2 columns]

# %%
[int(x.replace(',','')) for x in ReadUSD[0] if type(x)==str]
# Out:
# [300000, 1300000, 1000000, 4600000, 1100000]

# %%
New_df = [int(x.replace(',','')) for x in ReadUSD[0] if type(x)==str]

# %%
New_df
# Out:
# [300000, 1300000, 1000000, 4600000, 1100000]

# %%
ReadUSD = pd.read_excel(r'C:\Users\ayush\Desktop\Hubli Project\InvestmentModel\DoesItworkUSD.xlsx')

# %%
for x in ReadUSD[0]:
    if isinstance(x,str):
        print(x)

# %%
ReadUSD[0]
# Out:
# 0       200000000.0
# 1         8048394.0
# 2        18358860.0
# 3         3000000.0
# 4         1800000.0
#            ...
# 2071      2500000.0
# 2072      4500000.0
# 2073       825000.0
# 2074      1500000.0
# 2075       140000.0
# Name: 0, Length: 2076, dtype: float64

# %%
ReadUSD[0].between(10000,150000)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2071    False
# 2072    False
# 2073    False
# 2074    False
# 2075     True
# Name: 0, Length: 2076, dtype: bool

# %%
ReadUSD['RequiredRange'] = ReadUSD[0].between(10000,150000)

# %%
ReadUSD['RangeBoolean'] = ReadUSD[0].between(10000,150000)

# %% [markdown]
# # The final List of companies that fall in line with our ideals are

# %%
ReadUSD['RangeBoolean'].value_counts()
# Out:
# False    1871
# True      205
# Name: RangeBoolean, dtype: int64

# %%
ReadUSD
# Out:
#       Unnamed: 0            0  NewColumn  RangeBoolean  RequiredRange  \
# 0              0  200000000.0      False         False          False
# 1              1    8048394.0      False         False          False
# 2              2   18358860.0      False         False          False
# 3              3    3000000.0      False         False          False
# 4              4    1800000.0      False         False          False
# ...          ...          ...        ...           ...            ...
# 2071        2071    2500000.0      False         False          False
# 2072        2072    4500000.0      False         False          False
# 2073        2073     825000.0      False         False          False
# 2074        2074    1500000.0      False         False          False
# 2075        2075     140000.0       True          True           True
#
#       CheckRangeBelow  CheckRangeAbove  CheckRangeAbove15  FinalRange
# ...

# %%
ReadUSD['CheckRangeBelow'] = ReadUSD[0].between(1,100000)

# %%
ReadUSD['CheckRangeBelow'].value_counts()
# Out:
# False    1954
# True      122
# Name: CheckRangeBelow, dtype: int64

# %%
ReadUSD['CheckRangeAbove'] = ReadUSD[0].between(0,250000)

# %%
ReadUSD['CheckRangeAbove'].value_counts()
# Out:
# False    1724
# True      352
# Name: CheckRangeAbove, dtype: int64

# %%
ReadUSD['CheckRangeAbove15'] = ReadUSD[0].between(150000,200000)

# %%
ReadUSD['CheckRangeAbove15'].value_counts()
# Out:
# False    1953
# True      123
# Name: CheckRangeAbove15, dtype: int64

# %%
ReadUSD['FinalRange'] = ReadUSD[0].between(0,200000)

# %%
ReadUSD['FinalRange'].value_counts()
# Out:
# False    1793
# True      283
# Name: FinalRange, dtype: int64

# %%
CompleteUSD
# Out:
# 0           unknown
# 1       undisclosed
# 2       Undisclosed
# 3       undisclosed
# 4       undisclosed
#            ...
# 2079          16000
# 2080          16000
# 2081          16000
# 2082          16000
# 2083          16000
# Name: Amount in USD, Length: 2084, dtype: object

# %%
New_df
# Out:
#       Unnamed: 0  Sr No      Date dd/mm/yyyy     Startup Name  \
# 0             34     35  2019-10-21 00:00:00  The Man Company
# 1             20     21  2019-11-17 00:00:00     Burger Singh
# 2             58     59  2019-08-19 00:00:00   Mishry Reviews
# 3             89     90  2019-05-06 00:00:00     Ola Electric
# 4             91     92  2019-05-05 00:00:00       StyleDotMe
# ...          ...    ...                  ...              ...
# 3039        3027   3028  2015-05-21 00:00:00             Knit
# 3040        3030   3031  2015-01-22 00:00:00        Freshmonk
# 3041        3031   3032  2015-01-22 00:00:00  Englishleap.com
# 3042        3035   3036  2015-01-24 00:00:00         Impartus
# 3043        3042   3043  2015-01-30 00:00:00        Simplotel
#
#       Industry Vertical           SubVertical City  Location  \
# 0        Consumer Goods   Beauty and Grooming        Gurgaon
# 1     Food and Beverage   Indian Burger Brand        Gurgaon
# ...

# %%
New_df['Amount in USD'].dropna()
# Out:
# 0           unknown
# 1       undisclosed
# 2       Undisclosed
# 3       undisclosed
# 4       undisclosed
#            ...
# 2079          16000
# 2080          16000
# 2081          16000
# 2082          16000
# 2083          16000
# Name: Amount in USD, Length: 2084, dtype: object

# %%
New_df
# Out:
#       Unnamed: 0  Sr No      Date dd/mm/yyyy     Startup Name  \
# 0             34     35  2019-10-21 00:00:00  The Man Company
# 1             20     21  2019-11-17 00:00:00     Burger Singh
# 2             58     59  2019-08-19 00:00:00   Mishry Reviews
# 3             89     90  2019-05-06 00:00:00     Ola Electric
# 4             91     92  2019-05-05 00:00:00       StyleDotMe
# ...          ...    ...                  ...              ...
# 3039        3027   3028  2015-05-21 00:00:00             Knit
# 3040        3030   3031  2015-01-22 00:00:00        Freshmonk
# 3041        3031   3032  2015-01-22 00:00:00  Englishleap.com
# 3042        3035   3036  2015-01-24 00:00:00         Impartus
# 3043        3042   3043  2015-01-30 00:00:00        Simplotel
#
#       Industry Vertical           SubVertical City  Location  \
# 0        Consumer Goods   Beauty and Grooming        Gurgaon
# 1     Food and Beverage   Indian Burger Brand        Gurgaon
# ...
