# %%
from collections import Counter
import chart_studio
import chart_studio.plotly as py
import plotly.express as px
from pprint import pprint
from matplotlib.pyplot import figure
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_excel(r"C:\Users\ayush\Desktop\Hubli Project\InvestmentModel\CorrectData\BigDF.xlsx")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2070 entries, 0 to 2069
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          2070 non-null   int64
#  1   Sr No               2070 non-null   int64
#  2   Date dd/mm/yyyy     2070 non-null   datetime64[ns]
#  3   Startup Name        2070 non-null   object
#  4   Industry Vertical   1939 non-null   object
#  5   SubVertical         1416 non-null   object
#  6   City  Location      1935 non-null   object
#  7   Investors Name      2050 non-null   object
#  8   InvestmentnType     2069 non-null   object
#  9   Amount in USD       2070 non-null   int64
#  10  TierBoolean         2070 non-null   bool
#  11  AmountInUSDBoolean  2070 non-null   bool
#  12  Year                2070 non-null   int64
#  13  Month               2070 non-null   int64
# dtypes: bool(2), datetime64[ns](1), int64(5), object(6)
# memory usage: 198.2+ KB

# %%
df['OnlineMarketPlaceBoolean'] = df[df['SubVertical'].str.contains("Marketplace", case=False).fillna(False)]["SubVertical"].str.contains("Online").fillna(False)

# %%
df[df['OnlineMarketPlaceBoolean']==True]["SubVertical"].nunique()
# Out:
# 42

# %%
df['OnlineMarketPlaceBoolean'].fillna(False,inplace = True)

# %%
df['OnlineMarketPlaceBoolean'].value_counts()
# Out:
# False    2022
# True       48
# Name: OnlineMarketPlaceBoolean, dtype: int64

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Sr No', 'Date dd/mm/yyyy', 'Startup Name',
#        'Industry Vertical', 'SubVertical', 'City  Location', 'Investors Name',
#        'InvestmentnType', 'Amount in USD', 'TierBoolean', 'AmountInUSDBoolean',
#        'Year', 'Month', 'OnlineMarketPlaceBoolean'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Sr No', 'Date dd/mm/yyyy', 'Startup Name',
#        'Industry Vertical', 'SubVertical', 'City  Location', 'Investors Name',
#        'InvestmentnType', 'Amount in USD', 'TierBoolean', 'AmountInUSDBoolean',
#        'Year', 'Month', 'OnlineMarketPlaceBoolean'],
#       dtype='object')

# %%
df[df['SubVertical'].str.contains("Education", case=False).fillna(False)]
# Out:
#       Unnamed: 0  Sr No Date dd/mm/yyyy              Startup Name  \
# 29            29     31      2019-11-19  Furtados School of Music
# 36            36     39      2019-09-04                   3rdFlix
# 64            64     68      2019-07-10                "BYJU\\'S"
# 231          231    256      2018-06-28                   Edureka
# 258          258    286      2018-04-05               IndigoLearn
# 262          262    291      2018-04-09             Kriger Campus
# 313          313    355      2018-02-05              CollegeDekho
# 324          324    371      2018-02-14                Littlemore
# 325          325    372      2018-02-14                     Toppr
# 337          337    385      2018-02-26             Avishkaar Box
# 354          354    407      2018-01-17                     Rubix
# 359          359    413      2018-01-22             AEON Learning
# 364          364    419      2018-01-25                  GreyAtom
# ...

# %%
df['EducationBoolean'] = df['SubVertical'].str.contains("Education", case=False).fillna(False)

# %%
df["EducationBoolean"].value_counts()
# Out:
# False    2035
# True       35
# Name: EducationBoolean, dtype: int64

# %%
df[df['SubVertical'].str.contains("Commerce", case=False).fillna(False)].shape
# Out:
# (41, 16)

# %%
df[df["Industry Vertical"]=="eCommerce"].shape
# Out:
# (201, 16)

# %%
df.shape
# Out:
# (2070, 16)

# %% [markdown]
# ### In Consumer Internet these are the criteria on basis of which they got segregated (app, online, platform)

# %%
CIdf = df[df["Industry Vertical"]=="Consumer Internet"]

# %%
CIdf.shape
# Out:
# (589, 16)

# %%
df["EducationBool"]=CIdf['SubVertical'].str.contains("App" and "Online" and "Platform", case=False).fillna(False)

# %%
df['EducationBool'].fillna(False,inplace = True)

# %%
df['EducationBool'].value_counts()
# Out:
# False    1762
# True      308
# Name: EducationBool, dtype: int64

# %% [markdown]
# ### df.drop(['EducationBoolean'],axis = 1,inplace = True)

# %% [markdown]
# df.head(25)

# %%
df[df['SubVertical'].str.contains("Service", case=False).fillna(False)]
# Out:
#       Unnamed: 0  Sr No Date dd/mm/yyyy Startup Name    Industry Vertical  \
# 1              1      2      2020-01-13       Shuttl       Transportation
# 10            10     11      2019-12-13       Rivigo           Technology
# 20            20     22      2019-11-18   Healthians  Health and Wellness
# 22            22     24      2019-11-20  Aye Finance              FinTech
# 31            31     33      2019-10-04        Dunzo     Customer Service
# ...          ...    ...             ...          ...                  ...
# 1333        1333   1959      2016-02-16  BetterPlace           Technology
# 1346        1346   1985      2016-02-22      Taskbob    Consumer Internet
# 1349        1349   1990      2016-02-24       Sayfix    Consumer Internet
# 1351        1351   1993      2016-02-24   AppilyEver    Consumer Internet
# 1383        1383   2045      2016-01-13       Care24           Healthcare
#
#                                             SubVertical City  Location  \
# ...

# %%
df['ServiceInternetBoolean'] = df[df["Industry Vertical"]=="Consumer Internet"]['SubVertical'].str.contains("Service", case=False)

# %%
df['ServiceInternetBoolean'].fillna(False,inplace = True)

# %%
df['ServiceInternetBoolean'].value_counts()
# Out:
# False    2005
# True       65
# Name: ServiceInternetBoolean, dtype: int64

# %%
df.shape
# Out:
# (2070, 18)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Sr No', 'Date dd/mm/yyyy', 'Startup Name',
#        'Industry Vertical', 'SubVertical', 'City  Location', 'Investors Name',
#        'InvestmentnType', 'Amount in USD', 'TierBoolean', 'AmountInUSDBoolean',
#        'Year', 'Month', 'OnlineMarketPlaceBoolean', 'EducationBoolean',
#        'EducationBool', 'ServiceInternetBoolean'],
#       dtype='object')

# %%
df[df['SubVertical'].str.contains("Health", case=False).fillna(False)]
# Out:
#       Unnamed: 0  Sr No Date dd/mm/yyyy Startup Name    Industry Vertical  \
# 18            18     19      2019-11-14      Misters  Health and wellness
# 20            20     22      2019-11-18   Healthians  Health and Wellness
# 143          143    155      2018-09-04       3HCare           Healthcare
# 172          172    187      2018-08-27     MyUpchar           Healthcare
# 204          204    223      2018-07-30     Cure Fit    Consumer Internet
# ...          ...    ...             ...          ...                  ...
# 1301        1301   1902      2016-03-30     Touchkin           Healthcare
# 1315        1315   1924      2016-02-05    DawaiLelo    Consumer Internet
# 1338        1338   1971      2016-02-18  HealthKumbh    Consumer Internet
# 1345        1345   1983      2016-02-22    First Eat    Consumer Internet
# 1383        1383   2045      2016-01-13       Care24           Healthcare
#
#                                            SubVertical City  Location  \
# ...

# %%
try1 = df[df["Industry Vertical"]=="Consumer Internet"]

# %%
df['ServiceTechBoolean'] = df[df["Industry Vertical"]=="Consumer Internet"]['SubVertical'].str.contains("Service", case=False)

# %%
df['ServiceTechBoolean'].fillna(False,inplace=True)

# %%
df['ServiceTechBoolean'].value_counts()
# Out:
# False    2005
# True       65
# Name: ServiceTechBoolean, dtype: int64

# %%
df.drop(['ServiceTechBoolean'],axis=1,inplace = True)

# %%
df['HealthTechBoolean'] = df[df["Industry Vertical"]=="Consumer Internet"]['SubVertical'].str.contains("Health", case=False)

# %%
df['HealthTechBoolean'].fillna(False,inplace=True)
df['HealthTechBoolean'].value_counts()
# Out:
# False    2037
# True       33
# Name: HealthTechBoolean, dtype: int64

# %%
df[df['HealthTechBoolean']==True]
# Out:
#       Unnamed: 0  Sr No Date dd/mm/yyyy  Startup Name  Industry Vertical  \
# 204          204    223      2018-07-30      Cure Fit  Consumer Internet
# 288          288    325      2018-03-04    Livehealth  Consumer Internet
# 293          293    330      2018-03-12    HealthCare  Consumer Internet
# 499          499    594      2017-09-11   Call Health  Consumer Internet
# 500          500    596      2017-09-12        3HCare  Consumer Internet
# 519          519    631      2017-09-27      MyUpchar  Consumer Internet
# 523          523    637      2017-08-02  Click2Clinic  Consumer Internet
# 543          543    673      2017-08-29       CureFit  Consumer Internet
# 576          576    729      2017-06-06    wayForward  Consumer Internet
# 578          578    733      2017-06-07    GrowFitter  Consumer Internet
# 579          579    734      2017-06-08      Stratfit  Consumer Internet
# 602          602    764      2017-06-21      Grow Fit  Consumer Internet
# ...

# %%
df.shape
# Out:
# (2070, 19)

# %%
df[df['SubVertical'].str.contains("b2b", case=False).fillna(False)]
# Out:
#       Unnamed: 0  Sr No Date dd/mm/yyyy       Startup Name  Industry Vertical  \
# 27            27     29      2019-11-18       Medikabazaar         Healthcare
# 54            54     57      2019-08-21          HungerBox  Food and Beverage
# 300          300    338      2018-03-19  CustomerSucessBox         Technology
# 334          334    381      2018-02-21              Udaan          eCommerce
# 466          466    554      2017-10-18          BlackBuck          Logistics
# 477          477    568      2017-10-27         OfBusiness         Technology
# 483          483    575      2017-09-01       Aahaa Stores           eCommece
# 551          551    682      2017-07-05             Moglix          eCommerce
# 675          675    879      2017-04-11          Ninjacart          eCommerce
# 849          849   1147      2016-12-13         OfBusiness          eCommerce
# 901          901   1235      2016-11-23              Udaan          eCommerce
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Sr No', 'Date dd/mm/yyyy', 'Startup Name',
#        'Industry Vertical', 'SubVertical', 'City  Location', 'Investors Name',
#        'InvestmentnType', 'Amount in USD', 'TierBoolean', 'AmountInUSDBoolean',
#        'Year', 'Month', 'OnlineMarketPlaceBoolean', 'EducationBoolean',
#        'EducationBool', 'ServiceInternetBoolean', 'HealthTechBoolean'],
#       dtype='object')

# %%
df.drop("EducationBoolean",axis = 1, inplace = True)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Sr No', 'Date dd/mm/yyyy', 'Startup Name',
#        'Industry Vertical', 'SubVertical', 'City  Location', 'Investors Name',
#        'InvestmentnType', 'Amount in USD', 'TierBoolean', 'AmountInUSDBoolean',
#        'Year', 'Month', 'OnlineMarketPlaceBoolean', 'EducationBool',
#        'ServiceInternetBoolean', 'HealthTechBoolean'],
#       dtype='object')

# %%
df.shape
# Out:
# (2070, 18)

# %%
df["Amount in USD"].median()
# Out:
# 1725000.0

# %%
df['Amount in USD'].value_counts()
# Out:
# 1000000      166
# 500000       108
# 2000000       69
# 5000000       67
# 3000000       66
#             ...
# 306000         1
# 39000          1
# 270000000      1
# 329230         1
# 3250000        1
# Name: Amount in USD, Length: 454, dtype: int64

# %%
df["Quantile Rank"] = pd.qcut(df['Amount in USD'],10,labels = False)

# %%
df["Quantile Rank"]
# Out:
# 0       9
# 1       7
# 2       8
# 3       5
# 4       5
#        ..
# 2065    5
# 2066    6
# 2067    3
# 2068    4
# 2069    0
# Name: Quantile Rank, Length: 2070, dtype: int64

# %%
df.head(5)
# Out:
#    Unnamed: 0  Sr No Date dd/mm/yyyy                  Startup Name  \
# 0           0      1      2020-01-09                        BYJU’S
# 1           1      2      2020-01-13                        Shuttl
# 2           2      3      2020-01-09                     Mamaearth
# 3           3      4      2020-01-02  https://www.wealthbucket.in/
# 4           4      5      2020-01-02                        Fashor
#
#      Industry Vertical                            SubVertical City  Location  \
# 0               E-Tech                             E-learning      Bengaluru
# 1       Transportation              App based shuttle service        Gurgaon
# 2            eCommerce  Retailer of baby and toddler products      Bengaluru
# 3              FinTech                      Online Investment      New Delhi
# 4  Fashion and Apparel            Embroiled Clothes For Women         Mumbai
#
#               Investors Name       InvestmentnType  Amount in USD  \
# ...

# %%
df["Quantile Rank"].value_counts().sort_index(ascending=True).plot(kind='bar',color = 'r')
# Out:
# <AxesSubplot:>

# %%
df[df['InvestmentnType']=="Private Equity"]["Amount in USD"].median()
# Out:
# 6000000.0

# %%
df[df['InvestmentnType']=="Series A"]["Amount in USD"].median()
# Out:
# 4250000.0

# %%
# Decilel rank of Private equity based on Amount invested
pd.qcut(df[df["InvestmentnType"]=="Private Equity"]["Amount in USD"],10,labels=False).value_counts().sort_index(ascending= True).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
figure = plt.figure(figsize=(10,10))

plt.subplot(2,2,1)
pd.qcut(df[df["InvestmentnType"]=="Private Equity"]["Amount in USD"],10,labels=False).value_counts().sort_index(ascending= True).plot(kind='line')
plt.title("Private Equity USD distribution Decile")
plt.xlabel("Deciles")
plt.ylabel("Frequency")

plt.subplot(2,2,2)
pd.qcut(df[df["InvestmentnType"]=="Series A"]["Amount in USD"],10,labels=False).value_counts().sort_index(ascending= True).plot(kind='line')
plt.title("Series A USD distribution Decile")
plt.xlabel("Deciles")
plt.ylabel("Frequency")

plt.subplot(2,2,3)
df["Quantile Rank"].value_counts().sort_index(ascending=True).plot(kind='bar')
plt.title("Fund distribution Deciles")
plt.xlabel("Deciles")
plt.ylabel("Frequency")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,10))

a = pd.qcut(df[df["InvestmentnType"]=="Private Equity"]["Amount in USD"],10,labels=False).value_counts().sort_index(ascending= True).plot(kind='line',color = 'r')

b = pd.qcut(df[df["InvestmentnType"]=="Series A"]["Amount in USD"],10,labels=False).value_counts().sort_index(ascending= True).plot(kind='line',color = "Purple")

c = df["Quantile Rank"].value_counts().sort_index(ascending=True).plot(kind='bar')

# %%
x = np.linspace(0,1000,50)

plt.plot(x,a,color = 'r', label = "Private Equity")
plt.plot(x,b,color = 'o', label = "Series A")
plt.plot(x,c,color = 'b', label = "Whole")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-4c9d5f3d1ee6> in <module>
#       1 x = np.linspace(0,1000,50)
#       2
# ----> 3 plt.plot(x,a,color = 'r', label = "Private Equity")
#       4 plt.plot(x,b,color = 'o', label = "Series A")
#       5 plt.plot(x,c,color = 'b', label = "Whole")
#
# c:\users\ayush\appdata\local\programs\python\python39\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2755 @_copy_docstring_and_deprecators(Axes.plot)
#    2756 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2757     return gca().plot(
#    2758         *args, scalex=scalex, scaley=scaley,
#    2759         **({"data": data} if data is not None else {}), **kwargs)
#
# ...

# %%
df[df["Quantile Rank"]==4]["Amount in USD"].median()
# Out:
# 1400000.0

# %%
df["InvestmentnType"].value_counts()
# Out:
# Private Equity                 1072
# Seed Funding                    747
# Seed Angel Funding              104
# Debt Funding                     24
# Series A                         22
# Series B                         20
# Series C                         14
# Series D                         12
# Private Equity Round              4
# Pre-Series A                      4
# Angel   Seed Funding              4
# Seed                              4
# Venture Round                     2
# Seed  Angel Funding               2
# pre-Series A                      2
# Series F                          2
# Equity                            2
# Series E                          2
# Private Funding                   1
# Equity Based Funding              1
# Term Loan                         1
# Private                           1
# Series B (Extension)              1
# Mezzanine                         1
# Structured Debt                   1
# Debt-Funding                      1
# ...

# %%
df["InvestmentnType"].shape
# Out:
# (2070,)

# %%
2070-(1072+747)
# Out:
# 251

# %%
df["Quantile Rank"]
# Out:
# 0       9
# 1       7
# 2       8
# 3       5
# 4       5
#        ..
# 2065    5
# 2066    6
# 2067    3
# 2068    4
# 2069    0
# Name: Quantile Rank, Length: 2070, dtype: int64

# %%
df[df['InvestmentnType'].str.contains("series", case=False).fillna(False)]["Quantile Rank"].value_counts().sort_index(ascending = True).plot(kind='line',color = 'red')
# Out:
# <AxesSubplot:>

# %%
df[df['InvestmentnType'].str.contains("series", case=False).fillna(False)]["Quantile Rank"].value_counts().sort_index(ascending = True).plot(kind='line',color = 'red')
# Out:
# <AxesSubplot:>

# %%
df[df['InvestmentnType'].str.contains("series", case=False).fillna(False)]["Quantile Rank"].value_counts().sort_index(ascending = True).plot(kind='line',color = 'red')

df["Quantile Rank"].value_counts().sort_index(ascending=True).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## In the given 10 deciles that I have created, look for the proportion of companies that are in Series rounds as opposed to private equity and Seed

# %%
t1 = df["Quantile Rank"]==2

# %%
df[df["Amount in USD"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-63-81edc701f871> in <module>
# ----> 1 df[df["Amount in USD"]]
#
# c:\users\ayush\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# c:\users\ayush\appdata\local\programs\python\python39\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# ...

# %%
df[df["InvestmentnType"]=="Seed Funding"]
# Out:
#       Unnamed: 0  Sr No Date dd/mm/yyyy       Startup Name  \
# 4              4      5      2020-01-02             Fashor
# 14            14     15      2019-12-14              Trell
# 15            15     16      2019-12-11         Rein Games
# 23            23     25      2019-11-12        SuperGaming
# 26            26     28      2019-11-19  Digital Mall Asia
# ...          ...    ...             ...                ...
# 2057        2057   3027      2015-01-21       MyDreamStore
# 2058        2058   3029      2015-05-21            Villgro
# 2059        2059   3030      2015-01-22       Corporate360
# 2062        2062   3035      2015-01-24         Aasaanjobs
# 2069        2069   3044      2015-01-31   couponmachine.in
#
#         Industry Vertical                      SubVertical City  Location  \
# 4     Fashion and Apparel      Embroiled Clothes For Women         Mumbai
# 14                  Video    Experience Discovery Platform      Bengaluru
# ...

# %%
df[df["Quantile Rank"] == 2]["InvestmentnType"].value_counts()
# Out:
# Seed Funding            168
# Private Equity           24
# Seed Angel Funding       15
# Angel   Seed Funding      3
# Series B                  1
# Series A                  1
# Name: InvestmentnType, dtype: int64

# %%
df[df["Quantile Rank"] == 3]["InvestmentnType"].value_counts()
# Out:
# Seed Funding                154
# Private Equity              101
# Seed Angel Funding           22
# Series A                      3
# Debt Funding                  3
# Pre-Series A                  2
# Seed                          1
# Series J                      1
# Venture - Series Unknown      1
# Equity                        1
# Mezzanine                     1
# Name: InvestmentnType, dtype: int64

# %%
df[df["Quantile Rank"] == 5]["InvestmentnType"].value_counts()
# Out:
# Private Equity        162
# Seed Funding           22
# Seed Angel Funding     13
# Series A                3
# Debt Funding            2
# Pre-series A            1
# Pre-Series A            1
# pre-Series A            1
# Inhouse Funding         1
# Series E                1
# Name: InvestmentnType, dtype: int64

# %%
df[df["Quantile Rank"] == 9]["InvestmentnType"].value_counts()
# Out:
# Private Equity          163
# Series C                  9
# Series D                  9
# Series B                  6
# Private Equity Round      3
# Seed Funding              3
# Series A                  2
# Corporate Round           1
# Equity Based Funding      1
# Equity                    1
# Series F                  1
# Funding Round             1
# Single Venture            1
# Series H                  1
# Series G                  1
# Series E                  1
# Seed                      1
# Seed  Angel Funding       1
# Name: InvestmentnType, dtype: int64

# %%
df
# Out:
#       Unnamed: 0  Sr No Date dd/mm/yyyy                  Startup Name  \
# 0              0      1      2020-01-09                        BYJU’S
# 1              1      2      2020-01-13                        Shuttl
# 2              2      3      2020-01-09                     Mamaearth
# 3              3      4      2020-01-02  https://www.wealthbucket.in/
# 4              4      5      2020-01-02                        Fashor
# ...          ...    ...             ...                           ...
# 2065        2065   3039      2015-01-28                 Grabhouse.com
# 2066        2066   3040      2015-01-29                    Printvenue
# 2067        2067   3041      2015-01-29                      Graphene
# 2068        2068   3042      2015-01-30                Mad Street Den
# 2069        2069   3044      2015-01-31              couponmachine.in
#
#         Industry Vertical                            SubVertical  \
# ...

# %%
angelist = pd.read_csv(r"C:\Users\ayush\Desktop\Hubli Project\InvestmentModel\angelist_unique_4261.csv")

# %%
angelist.shape
# Out:
# (4261, 12)

# %%
angelist['market'].nunique()
# Out:
# 601

# %%
df['Industry Vertical'].nunique()
# Out:
# 585

# %%
angelist['market'].dropna().unique()
# Out:
# array(['Mobile Commerce', 'SaaS', 'Politics',
#        'Small and Medium Businesses', 'Video Streaming', 'Polling',
#        'Bitcoin', 'Developer APIs', 'B2B', 'Apps', 'Nonprofits',
#        'Banking', 'Manufacturing', 'Consumer Electronics',
#        'Language Learning', 'Loyalty Programs', 'Mobile Games',
#        'Hospitality', 'E-Commerce', 'Fitness', 'Location Based Services',
#        'Mobile Payments', 'Optimization',
#        'Health Care Information Technology', 'User Experience Design',
#        'Outdoor Advertising', 'Retail Technology', 'Test and Measurement',
#        'Mobile Coupons', 'Native Advertising', 'University Students',
#        'Augmented Reality', 'Digital Publishing', 'College Recruiting',
#        'Medical Devices', 'Diagnostics', 'Human Resources',
#        'Social Recruiting', 'Contact Management', 'Advertising Platforms',
#        'Universities', 'Fantasy Sports', 'Corporate Wellness',
#        'Virtualization', 'Crowdsourcing', 'Hong Kong',
# ...

# %%
df["Industry Vertical"].dropna().unique()
# Out:
# array(['E-Tech', 'Transportation', 'eCommerce', 'FinTech',
#        'Fashion and Apparel', 'Logistics', 'Hospitality', 'Technology',
#        'Aerospace', 'B2B-focused foodtech startup', 'Finance', 'Video',
#        'Gaming', 'Software', 'Health and wellness', 'Education',
#        'Health and Wellness', 'B2B Marketing', 'Video Games', 'SaaS',
#        'Last Mile Transportation', 'Healthcare', 'Customer Service',
#        'B2B', 'Advertising, Marketing', 'IoT', 'Information Technology',
#        'Consumer Technology', 'Accounting', 'Retail',
#        'Customer Service Platform', 'Automotive', 'Consumer Goods',
#        'Food and Beverage', 'EdTech', 'Compliance', 'Transport',
#        'Artificial Intelligence', 'Tech', 'Health Care', 'Luxury Label',
#        'Waste Management Service', 'Deep-Tech', 'Energy', 'Digital Media',
#        'Services', 'Saas', 'Automobile', 'Agtech', 'Social Media',
#        'Fintech', 'Edtech', 'Nanotechnology', 'Services Platform',
# ...

# %%
df[df['SubVertical'].str.contains("Marketplace", case=False).fillna(False)]["SubVertical"].str.contains("Online").fillna(False)
# Out:
# 34      False
# 107      True
# 111     False
# 144      True
# 146      True
#         ...
# 1377    False
# 1381    False
# 1392    False
# 1393    False
# 1414     True
# Name: SubVertical, Length: 99, dtype: bool

# %%
df[df['Industry Vertical']=="Healthcare"]['SubVertical'].unique()
# Out:
# array(['B2B platform for medical supplies', 'Healthcare Service Provider',
#        'Online Marketplace For Mother and Babycare Products',
#        'Local Language Health Content App',
#        'Home diagnostics services provider',
#        'A Doctor-Patient Engagement Platform',
#        'Health and Well being Platform',
#        'An Online Platform That Connects Ayurveda Doctors With Patients',
#        'Prosthetics Manufacturers',
#        'Data Driven Intelligence Solutions Platform',
#        'Doctor-Consultation App', 'Home Healthcare Aggregator',
#        'Platform To Discover Healthcare Financing Options',
#        'Digitized Health-Tech Solutions For Practitioners',
#        'Therapeutics',
#        'Genetic Screening, DNA Diagnostics Labs & Research Centers',
#        'Technology enabled equitable healthcare for India',
#        'Super-specialty Hospital', 'Preventive Health Checkup',
#        'Online Portal for Diet,fitness and Beauty',
# ...

# %%
df[df['SubVertical'].str.contains("Service", case=False).fillna(False)].head(20)
# Out:
#      Unnamed: 0  Sr No Date dd/mm/yyyy                     Startup Name  \
# 1             1      2      2020-01-13                           Shuttl
# 10           10     11      2019-12-13                           Rivigo
# 20           20     22      2019-11-18                       Healthians
# 22           22     24      2019-11-20                      Aye Finance
# 31           31     33      2019-10-04                            Dunzo
# 33           33     36      2019-09-05                 FPL Technologies
# 80           80     86      2019-06-10                         OkCredit
# 111         111    121      2018-12-01  UrbanClap Technologies Pvt. Ltd
# 123         123    133      2018-11-12                       MilkBAsket
# 143         143    155      2018-09-04                           3HCare
# 167         167    182      2018-08-20                      RawPressery
# 179         179    195      2018-07-09                         zippserv
# ...

# %%
df['SubVertical'].dropna().shape
# Out:
# (1416,)

# %%
angelist
# Out:
#       Unnamed: 0   joined     kind                                     link  \
# 0             35  Oct ’13  Startup             https://angel.co/company/urx
# 1           2288  May ’12  Startup            https://angel.co/company/ginx
# 2          11708  Sep ’11  Startup          https://angel.co/company/1-page
# 3          11471  Apr ’12  Startup        https://angel.co/company/121nexus
# 4           6887  Nov ’13  Startup       https://angel.co/company/1234enter
# ...          ...      ...      ...                                      ...
# 4256        2201  Feb ’14  Startup           https://angel.co/company/zoovu
# 4257          64  Mar ’12  Startup  https://angel.co/company/entrobit-agora
# 4258         548  Dec ’13  Startup          https://angel.co/company/shwrum
# 4259        4637  Oct ’15  Startup   https://angel.co/company/stars-company
# 4260           0      NaN      NaN                                      NaN
#
# ...

# %%
df.c
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-81-90d61cc1a0c4> in <module>
# ----> 1 df.c
#
# c:\users\ayush\appdata\local\programs\python\python39\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'c'

# %%
df["Industry Vertical"].value_counts().head(10)
# Out:
# Consumer Internet    589
# Technology           310
# eCommerce            201
# Finance               57
# Healthcare            44
# Logistics             23
# Education             19
# Food & Beverage       15
# Ed-Tech               12
# FinTech                9
# Name: Industry Vertical, dtype: int64

# %%
angelist['market'].value_counts().head(10)
# Out:
# Mobile Commerce                151
# SaaS                           108
# B2B                            108
# Mobile Games                   100
# Location Based Services         92
# Small and Medium Businesses     88
# Mobile Advertising              80
# K-12 Education                  69
# Mobile Health                   66
# Social Media Platforms          63
# Name: market, dtype: int64

# %%
df[df["SubVertical"].str.contains("service",case =False).dropna()]
# Out:
# <ipython-input-84-7a0e0f7fd0ef>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df["SubVertical"].str.contains("service",case =False).dropna()]
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-84-7a0e0f7fd0ef> in <module>
# ----> 1 df[df["SubVertical"].str.contains("service",case =False).dropna()]
#
# c:\users\ayush\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3447         # Do we have a (boolean) 1d indexer?
#    3448         if com.is_bool_indexer(key):
# -> 3449             return self._getitem_bool_array(key)
#    3450
#    3451         # We are left with two options: a single key, and a collection of keys,
#
# c:\users\ayush\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py in _getitem_bool_array(self, key)
# ...

# %% [markdown]
# # try1 = df[df["Industry Vertical"]=="Consumer Internet"]

# %% [markdown]
# # try1.to_excel('send.xlsx')

# %%
angelist['market'].unique()
# Out:
# array(['Mobile Commerce', 'SaaS', 'Politics',
#        'Small and Medium Businesses', 'Video Streaming', 'Polling',
#        'Bitcoin', 'Developer APIs', 'B2B', 'Apps', 'Nonprofits',
#        'Banking', 'Manufacturing', 'Consumer Electronics',
#        'Language Learning', 'Loyalty Programs', nan, 'Mobile Games',
#        'Hospitality', 'E-Commerce', 'Fitness', 'Location Based Services',
#        'Mobile Payments', 'Optimization',
#        'Health Care Information Technology', 'User Experience Design',
#        'Outdoor Advertising', 'Retail Technology', 'Test and Measurement',
#        'Mobile Coupons', 'Native Advertising', 'University Students',
#        'Augmented Reality', 'Digital Publishing', 'College Recruiting',
#        'Medical Devices', 'Diagnostics', 'Human Resources',
#        'Social Recruiting', 'Contact Management', 'Advertising Platforms',
#        'Universities', 'Fantasy Sports', 'Corporate Wellness',
#        'Virtualization', 'Crowdsourcing', 'Hong Kong',
# ...

# %%
angelist['market'].value_counts().head(10)
# Out:
# Mobile Commerce                151
# SaaS                           108
# B2B                            108
# Mobile Games                   100
# Location Based Services         92
# Small and Medium Businesses     88
# Mobile Advertising              80
# K-12 Education                  69
# Mobile Health                   66
# Social Media Platforms          63
# Name: market, dtype: int64

# %%
df['Industry Vertical'].value_counts().head(10)
# Out:
# Consumer Internet    589
# Technology           310
# eCommerce            201
# Finance               57
# Healthcare            44
# Logistics             23
# Education             19
# Food & Beverage       15
# Ed-Tech               12
# FinTech                9
# Name: Industry Vertical, dtype: int64

# %%
df.drop("Unnamed: 0",axis =1 ,inplace = True)

# %%
df.columns
# Out:
# Index(['Sr No', 'Date dd/mm/yyyy', 'Startup Name', 'Industry Vertical',
#        'SubVertical', 'City  Location', 'Investors Name', 'InvestmentnType',
#        'Amount in USD', 'TierBoolean', 'AmountInUSDBoolean', 'Year', 'Month',
#        'OnlineMarketPlaceBoolean', 'EducationBool', 'ServiceInternetBoolean',
#        'HealthTechBoolean', 'Quantile Rank'],
#       dtype='object')

# %%
df[df['Quantile Rank']==1]['Amount in USD'].max()
# Out:
# 320000

# %%
df[df['Quantile Rank']==1]['Amount in USD'].min()
# Out:
# 156000

# %%
df[df['Quantile Rank']==1]['Amount in USD'].nunique()
# Out:
# 57

# %%
df[df['Quantile Rank']==0]['Amount in USD'].max()
# Out:
# 155000

# %%
df[df['Quantile Rank']==0]['Amount in USD'].min()
# Out:
# 16000

# %%
df[df['Quantile Rank']==0]['Amount in USD'].nunique()
# Out:
# 49

# %%
df["Quantile Rank"].value_counts().sum()
# Out:
# 2070

# %%
df[df['Quantile Rank']==1]['Amount in USD'].max()
# Out:
# 320000

# %%
df[df['Quantile Rank']==1]['Amount in USD'].min()
# Out:
# 156000

# %%
df[df['Quantile Rank']==0]['Amount in USD'].min()
# Out:
# 16000

# %%
df[df['Quantile Rank']==0]['Amount in USD'].max()
# Out:
# 155000

# %%
df[df["Quantile Rank"]==0]["Quantile Rank"] = str()
# Out:
# <ipython-input-101-dfcff1990d82>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df["Quantile Rank"]==0]["Quantile Rank"] = str()

# %%
df[df['Industry Vertical']=='Consumer Internet']["SubVertical"].str.contains("fitness")
# Out:
# 140     False
# 142     False
# 144     False
# 145     False
# 148     False
#         ...
# 1405    False
# 1406    False
# 1411    False
# 1412    False
# 1413    False
# Name: SubVertical, Length: 589, dtype: bool

# %%
df[df["Industry Vertical"]=="Consumer Internet"]['SubVertical'].str.contains("fitness", case=False)
# Out:
# 140     False
# 142     False
# 144     False
# 145     False
# 148     False
#         ...
# 1405    False
# 1406    False
# 1411     True
# 1412    False
# 1413    False
# Name: SubVertical, Length: 589, dtype: bool

# %%
df.columns
# Out:
# Index(['Sr No', 'Date dd/mm/yyyy', 'Startup Name', 'Industry Vertical',
#        'SubVertical', 'City  Location', 'Investors Name', 'InvestmentnType',
#        'Amount in USD', 'TierBoolean', 'AmountInUSDBoolean', 'Year', 'Month',
#        'OnlineMarketPlaceBoolean', 'EducationBool', 'ServiceInternetBoolean',
#        'HealthTechBoolean', 'Quantile Rank'],
#       dtype='object')

# %%
a = df[df["Industry Vertical"]=="Consumer Internet"]["SubVertical"]

# %%
df[df["SubVertical"].str.contains("Online").fillna(False)]["Industry Vertical"]=="Consumer Internet"
# Out:
# 3       False
# 6       False
# 12      False
# 16      False
# 81      False
#         ...
# 1397     True
# 1398     True
# 1406     True
# 1411     True
# 1414    False
# Name: Industry Vertical, Length: 337, dtype: bool

# %%
df.columns
# Out:
# Index(['Sr No', 'Date dd/mm/yyyy', 'Startup Name', 'Industry Vertical',
#        'SubVertical', 'City  Location', 'Investors Name', 'InvestmentnType',
#        'Amount in USD', 'TierBoolean', 'AmountInUSDBoolean', 'Year', 'Month',
#        'OnlineMarketPlaceBoolean', 'EducationBool', 'ServiceInternetBoolean',
#        'HealthTechBoolean', 'Quantile Rank'],
#       dtype='object')

# %%
df.shape
# Out:
# (2070, 18)

# %%
df.to_excel("ChangeKar.xlsx")

# %%
df = pd.read_excel('ChangeKar.xlsx')

# %%
df['Industry Vertical'].value_counts().head(10)
# Out:
# Consumer Internet    589
# Technology           310
# eCommerce            201
# Finance               57
# Healthcare            44
# Logistics             23
# Education             19
# Food & Beverage       15
# Ed-Tech               12
# FinTech                9
# Name: Industry Vertical, dtype: int64

# %%
df[df['Industry Vertical']=='Finance']['Industry Vertical'].value_counts()
# Out:
# Finance    57
# Name: Industry Vertical, dtype: int64

# %%
df[df['Industry Vertical']=='Finance']['Industry Vertical'].value_counts()
# Out:
# Finance    57
# Name: Industry Vertical, dtype: int64

# %%
df = pd.read_excel("ChangeKar.xlsx")

# %%
df["Industry Vertical"].value_counts().head(15)
# Out:
# Consumer Internet       589
# Technology              310
# eCommerce               201
# Finance                  57
# Healthcare               44
# Logistics                23
# Education                19
# Food & Beverage          15
# Ed-Tech                  12
# FinTech                   9
# IT                        8
# Fin-Tech                  6
# Food and Beverage         5
# Online Food Delivery      5
# Health and Wellness       5
# Name: Industry Vertical, dtype: int64

# %%
df["Industry Vertical"].value_counts().head(10).plot(kind ="bar")
plt.title("Top Industries in India")
# Out:
# Text(0.5, 1.0, 'Top Industries in India')

# %%
angelist['market'].value_counts().head(10).plot(kind='bar')
plt.title("Top Industries Worldwide")
# Out:
# Text(0.5, 1.0, 'Top Industries Worldwide')

# %%
angelist['market'].value_counts().head(10).median()
# Out:
# 90.0

# %%
df["Industry Vertical"].value_counts().head(10).median()
# Out:
# 33.5

# %%
angelist['market'].nunique()
# Out:
# 601

# %%
df['InvestmentnType'].value_counts()
# Out:
# Private Equity                 1072
# Seed Funding                    747
# Seed Angel Funding              104
# Debt Funding                     24
# Series A                         22
# Series B                         20
# Series C                         14
# Series D                         12
# Private Equity Round              4
# Pre-Series A                      4
# Angel   Seed Funding              4
# Seed                              4
# Venture Round                     2
# Seed  Angel Funding               2
# pre-Series A                      2
# Series F                          2
# Equity                            2
# Series E                          2
# Private Funding                   1
# Equity Based Funding              1
# Term Loan                         1
# Private                           1
# Series B (Extension)              1
# Mezzanine                         1
# Structured Debt                   1
# Debt-Funding                      1
# ...

# %%
angelist.stage.value_counts()
# Out:
# Seed        1944
# Series A     540
# Acquired     425
# Series B     285
# Series C     188
# -            172
# Series D      69
# Closed        49
# Series E      26
# IPO           16
# Pre-Seed       7
# Series F       7
# Series G       2
# Name: stage, dtype: int64

# %% [markdown]
# ###  what I can do is, in my dataset, I can make a range of private equity to fit into the range of series A funding
# ### Also I can add the feature of number of investors into the mix as well

# %%
df["Investors Name"]
# Out:
# 0                 Tiger Global Management
# 1               Susquehanna Growth Equity
# 2                   Sequoia Capital India
# 3                          Vinod Khatumal
# 4                 Sprout Venture Partners
#                       ...
# 2065     Kalaari Capital, Sequoia Capital
# 2066          Asia Pacific Internet Group
# 2067                       KARSEMVEN Fund
# 2068       Exfinity Fund, GrowX Ventures.
# 2069    UK based Group of Angel Investors
# Name: Investors Name, Length: 2070, dtype: object

# %%
df["Investors Name"].str.count(',')+1
# Out:
# 0       1.0
# 1       1.0
# 2       1.0
# 3       1.0
# 4       1.0
#        ...
# 2065    2.0
# 2066    1.0
# 2067    1.0
# 2068    2.0
# 2069    1.0
# Name: Investors Name, Length: 2070, dtype: float64

# %%
df["Number_Investors"] = df['Investors Name'].str.count(',')+1

# %%
df["Number_Investors"] = df['Number_Investors'].fillna(0).astype(np.int64)

# %%
df.dtypes
# Out:
# Unnamed: 0                           int64
# Sr No                                int64
# Date dd/mm/yyyy             datetime64[ns]
# Startup Name                        object
# Industry Vertical                   object
# SubVertical                         object
# City  Location                      object
# Investors Name                      object
# InvestmentnType                     object
# Amount in USD                        int64
# TierBoolean                           bool
# AmountInUSDBoolean                    bool
# Year                                 int64
# Month                                int64
# OnlineMarketPlaceBoolean              bool
# EducationBool                         bool
# ServiceInternetBoolean                bool
# HealthTechBoolean                     bool
# Quantile Rank                        int64
# Number_Investors                     int64
# dtype: object

# %%
df[df['Number_Investors']==0]
# Out:
#       Unnamed: 0  Sr No Date dd/mm/yyyy               Startup Name  \
# 13            13     14      2019-12-16                     InCred
# 44            44     47      2019-08-01               MyPetrolPump
# 143          143    155      2018-09-04                     3HCare
# 154          154    169      2018-08-07                  My OmNamo
# 164          164    179      2018-08-16                    Enakshi
# 166          166    181      2018-08-20                      Finzy
# 174          174    189      2018-08-30                 True North
# 192          192    209      2018-07-20                 HousingMan
# 235          235    261      2018-05-07                 PaisaDukan
# 256          256    284      2018-04-02                      Finzy
# 262          262    291      2018-04-09              Kriger Campus
# 273          273    307      2018-04-23                     Mihuru
# 305          305    346      2018-03-28                   Roadcast
# ...

# %% [markdown]
# ### Here I will describe the Ranges that I have used to seggregate the data about Private Equity
#
# # Range of 0 to 500k Dollar would be Seed
# # Range of 500k to 1.25M Dollar would be pre Series A
# # Range of 1.25M to 7M  Dollar would Series A
# # Range of 7M to 20M would be Series B

# %% [markdown]
# ## obtaining values of angelist data and organising to see the mean values of investment made

# %%
angelist[angelist['stage']=='Seed']['raised'].mean()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\users\ayush\appdata\local\programs\python\python39\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#    1601         try:
# -> 1602             x = float(x)
#    1603         except (TypeError, ValueError):
#
# ...

# %%
angelist['raised'].fillna(0).replace('$ ','',regex=True)
# Out:
# 0        $ 15,100,000
# 1           $ 700,000
# 2       $ 163,000,000
# 3           $ 794,000
# 4           $ 650,267
#             ...
# 4256      $ 6,000,000
# 4257        $ 450,000
# 4258         $ 50,000
# 4259        $ 300,000
# 4260                0
# Name: raised, Length: 4261, dtype: object

# %%
angelist['raised']
# Out:
# 0        $ 15,100,000
# 1           $ 700,000
# 2       $ 163,000,000
# 3           $ 794,000
# 4           $ 650,267
#             ...
# 4256      $ 6,000,000
# 4257        $ 450,000
# 4258         $ 50,000
# 4259        $ 300,000
# 4260              NaN
# Name: raised, Length: 4261, dtype: object

# %%
angelist['raisedNUM'] = angelist['raised'].fillna(0).replace(',','')

# %%
type(angelist['raisedNUM'][3])
# Out:
# str

# %%
angelist.dtypes.astype(np.int64)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-134-29f03e018996> in <module>
# ----> 1 angelist.dtypes.astype(np.int64)
#
# c:\users\ayush\appdata\local\programs\python\python39\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# c:\users\ayush\appdata\local\programs\python\python39\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
# ...

# %%
angelist['raised'].replace(regex=['$ '], value='')
# Out:
# 0        $ 15,100,000
# 1           $ 700,000
# 2       $ 163,000,000
# 3           $ 794,000
# 4           $ 650,267
#             ...
# 4256      $ 6,000,000
# 4257        $ 450,000
# 4258         $ 50,000
# 4259        $ 300,000
# 4260              NaN
# Name: raised, Length: 4261, dtype: object

# %%
angelist['raised'].str.replace('$', '')
# Out:
# <ipython-input-136-f944d49575ba>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   angelist['raised'].str.replace('$', '')
# 0         15,100,000
# 1            700,000
# 2        163,000,000
# 3            794,000
# 4            650,267
#             ...
# 4256       6,000,000
# 4257         450,000
# 4258          50,000
# 4259         300,000
# 4260             NaN
# Name: raised, Length: 4261, dtype: object

# %%
angelist['raised'].str.replace(',','').fillna(0)
# Out:
# 0        $ 15100000
# 1          $ 700000
# 2       $ 163000000
# 3          $ 794000
# 4          $ 650267
#            ...
# 4256      $ 6000000
# 4257       $ 450000
# 4258        $ 50000
# 4259       $ 300000
# 4260              0
# Name: raised, Length: 4261, dtype: object

# %%
angelist['raisedNUM']=angelist['raised'].str.replace(',','',regex = True).fillna(0)

# %%
angelist['raisedNUM'] = angelist['raisedNUM'].str.replace(' ','')

# %%
angelist['raisedNUM'] = angelist['raisedNUM'].str.replace('€','')
angelist['raisedNUM'] = angelist['raisedNUM'].str.replace('£','')

# %%
angelist['raisedNUM']=angelist['raisedNUM'].fillna(0).astype(np.int64)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-141-d5bc678cba36> in <module>
# ----> 1 angelist['raisedNUM']=angelist['raisedNUM'].fillna(0).astype(np.int64)
#
# c:\users\ayush\appdata\local\programs\python\python39\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# c:\users\ayush\appdata\local\programs\python\python39\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# ...

# %%
angelist[angelist['stage']=='Seed']['raisedNUM'].mean()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\users\ayush\appdata\local\programs\python\python39\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#    1601         try:
# -> 1602             x = float(x)
#    1603         except (TypeError, ValueError):
#
# ...

# %%
angelist[angelist['stage']=='Seed']['raisedNUM'].median()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\users\ayush\appdata\local\programs\python\python39\lib\site-packages\pandas\core\nanops.py in nanmedian(values, axis, skipna, mask)
#     718         try:
# --> 719             values = values.astype("f8")
#     720         except ValueError as err:
#
# ValueError: could not convert string to float: '$700000'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-143-8f9f63504725> in <module>
# ----> 1 angelist[angelist['stage']=='Seed']['raisedNUM'].median()
#
# c:\users\ayush\appdata\local\programs\python\python39\lib\site-packages\pandas\core\generic.py in median(self, axis, skipna, level, numeric_only, **kwargs)
#   10800             self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs
# ...

# %% [markdown]
# ## Looking at the numbers we can infer that the amount of money that is being invested in Seed stage startups globally

# %%
angelist.columns
# Out:
# Index(['Unnamed: 0', 'joined', 'kind', 'link', 'location', 'market', 'name',
#        'pitch', 'raised', 'size', 'stage', 'website', 'raisedNUM'],
#       dtype='object')

# %%
angelist['stage'].value_counts().plot(kind='bar')
plt.title("angelist funding Distribution")
# Out:
# Text(0.5, 1.0, 'angelist funding Distribution')

# %%
df['tryColumnForInvestment'].value_counts().head(10).plot(kind='bar')
plt.title("Earlier funding Distribution")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\ayush\appdata\local\programs\python\python39\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# c:\users\ayush\appdata\local\programs\python\python39\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# c:\users\ayush\appdata\local\programs\python\python39\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'tryColumnForInvestment'
#
# ...

# %%
angelist[angelist['stage']=='Series A']['raisedNUM'].median()

# %%
df['tryColumnForInvestment'] = df['InvestmentnType']

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Sr No', 'Date dd/mm/yyyy', 'Startup Name',
#        'Industry Vertical', 'SubVertical', 'City  Location', 'Investors Name',
#        'InvestmentnType', 'Amount in USD', 'TierBoolean', 'AmountInUSDBoolean',
#        'Year', 'Month', 'OnlineMarketPlaceBoolean', 'EducationBool',
#        'ServiceInternetBoolean', 'HealthTechBoolean', 'Quantile Rank',
#        'Number_Investors', 'tryColumnForInvestment'],
#       dtype='object')

# %%
df[df["InvestmentnType"]=='Seed Funding']['Amount in USD'].median()
# Out:
# 325000.0

# %%
print("Seed Angel Funding Funding mean : ", df[df["InvestmentnType"]=='Seed Angel Funding']['Amount in USD'].mean())
print("Seed Angel Funding Funding median : ", df[df["InvestmentnType"]=='Seed Angel Funding']['Amount in USD'].median())
print("Seed Angel Funding Funding max : ", df[df["InvestmentnType"]=='Seed Angel Funding']['Amount in USD'].max())
print("Seed Angel Funding Funding min : ", df[df["InvestmentnType"]=='Seed Angel Funding']['Amount in USD'].min())
# Out:
# Seed Angel Funding Funding mean :  1192790.4807692308
# Seed Angel Funding Funding median :  742500.0
# Seed Angel Funding Funding max :  12000000
# Seed Angel Funding Funding min :  39000

# %%
print("Series B Funding mean : ", df[df["InvestmentnType"]=='Series B']['Amount in USD'].mean())
print("Series B Funding median : ", df[df["InvestmentnType"]=='Series B']['Amount in USD'].median())
print("Series B Funding max : ", df[df["InvestmentnType"]=='Series B']['Amount in USD'].max())
print("Series B Funding min : ", df[df["InvestmentnType"]=='Series B']['Amount in USD'].min())
# Out:
# Series B Funding mean :  239959786.75
# Series B Funding median :  15900000.0
# Series B Funding max :  3900000000
# Series B Funding min :  486000

# %%
print("Private Equity Funding mean : ", df[df["InvestmentnType"]=='Private Equity']['Amount in USD'].mean())
print("Private Equity Funding median : ", df[df["InvestmentnType"]=='Private Equity']['Amount in USD'].median())
print("Private Equity Funding max : ", df[df["InvestmentnType"]=='Private Equity']['Amount in USD'].max())
print("Private Equity Funding min : ", df[df["InvestmentnType"]=='Private Equity']['Amount in USD'].min())
# Out:
# Private Equity Funding mean :  24919653.138992537
# Private Equity Funding median :  6000000.0
# Private Equity Funding max :  2500000000
# Private Equity Funding min :  100000

# %%
print("Series A Funding mean : ", df[df["InvestmentnType"]=='Series A']['Amount in USD'].mean())
print("Series A Funding median : ", df[df["InvestmentnType"]=='Series A']['Amount in USD'].median())
print("Series A Funding max : ", df[df["InvestmentnType"]=='Series A']['Amount in USD'].max())
print("Series A Funding min : ", df[df["InvestmentnType"]=='Series A']['Amount in USD'].min())
# Out:
# Series A Funding mean :  9236363.636363637
# Series A Funding median :  4250000.0
# Series A Funding max :  45000000
# Series A Funding min :  500000

# %%
print("Seed Funding mean : ", df[df["InvestmentnType"]=='Seed Funding']['Amount in USD'].mean())
print("Seed Funding median : ", df[df["InvestmentnType"]=='Seed Funding']['Amount in USD'].median())
print("Seed Funding max : ", df[df["InvestmentnType"]=='Seed Funding']['Amount in USD'].max())
print("Seed Funding min : ", df[df["InvestmentnType"]=='Seed Funding']['Amount in USD'].min())
# Out:
# Seed Funding mean :  1038448.3373493976
# Seed Funding median :  325000.0
# Seed Funding max :  220000000
# Seed Funding min :  16000

# %%
import pandas as pd
pd.options.mode.chained_assignment = None  # default='warn'

# %%
df['InvestmentnType'].value_counts()
# Out:
# Private Equity                 1072
# Seed Funding                    747
# Seed Angel Funding              104
# Debt Funding                     24
# Series A                         22
# Series B                         20
# Series C                         14
# Series D                         12
# Private Equity Round              4
# Pre-Series A                      4
# Angel   Seed Funding              4
# Seed                              4
# Venture Round                     2
# Seed  Angel Funding               2
# pre-Series A                      2
# Series F                          2
# Equity                            2
# Series E                          2
# Private Funding                   1
# Equity Based Funding              1
# Term Loan                         1
# Private                           1
# Series B (Extension)              1
# Mezzanine                         1
# Structured Debt                   1
# Debt-Funding                      1
# ...

# %%
df[(df["InvestmentnType"]=="Private Equity") & (df["Amount in USD"].between(1600,450000))]['tryColumnForInvestment']="Seed Funding"

# %%
df[(df["InvestmentnType"]=="Private Equity") & (df["Amount in USD"].between(1600,450000))]['tryColumnForInvestment']
# Out:
# 93      Private Equity
# 153     Private Equity
# 305     Private Equity
# 325     Private Equity
# 745     Private Equity
# 919     Private Equity
# 1041    Private Equity
# 1129    Private Equity
# 1155    Private Equity
# 1160    Private Equity
# 1190    Private Equity
# 1249    Private Equity
# 1293    Private Equity
# Name: tryColumnForInvestment, dtype: object

# %% [markdown]
# ### df.to_excel('FinalFinalFinalSheet.xlsx')

# %%
df['tryColumnForInvestment'].value_counts()
# Out:
# Private Equity                 1072
# Seed Funding                    747
# Seed Angel Funding              104
# Debt Funding                     24
# Series A                         22
# Series B                         20
# Series C                         14
# Series D                         12
# Private Equity Round              4
# Pre-Series A                      4
# Angel   Seed Funding              4
# Seed                              4
# Venture Round                     2
# Seed  Angel Funding               2
# pre-Series A                      2
# Series F                          2
# Equity                            2
# Series E                          2
# Private Funding                   1
# Equity Based Funding              1
# Term Loan                         1
# Private                           1
# Series B (Extension)              1
# Mezzanine                         1
# Structured Debt                   1
# Debt-Funding                      1
# ...

# %%
df['tryColumnForInvestment'].value_counts()
# Out:
# Private Equity                 1072
# Seed Funding                    747
# Seed Angel Funding              104
# Debt Funding                     24
# Series A                         22
# Series B                         20
# Series C                         14
# Series D                         12
# Private Equity Round              4
# Pre-Series A                      4
# Angel   Seed Funding              4
# Seed                              4
# Venture Round                     2
# Seed  Angel Funding               2
# pre-Series A                      2
# Series F                          2
# Equity                            2
# Series E                          2
# Private Funding                   1
# Equity Based Funding              1
# Term Loan                         1
# Private                           1
# Series B (Extension)              1
# Mezzanine                         1
# Structured Debt                   1
# Debt-Funding                      1
# ...

# %%
wesee = pd.read_excel("FinalFinalFinalSheet.xlsx")

# %%
wesee.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'Unnamed: 0.1.1', 'Sr No',
#        'Date dd/mm/yyyy', 'Startup Name', 'Industry Vertical', 'SubVertical',
#        'City  Location', 'Investors Name', 'InvestmentnType', 'Amount in USD',
#        'TierBoolean', 'AmountInUSDBoolean', 'Year', 'Month',
#        'OnlineMarketPlaceBoolean', 'EducationBool', 'ServiceInternetBoolean',
#        'HealthTechBoolean', 'Quantile Rank', 'Number_Investors',
#        'tryColumnForInvestment', 'Reached_Series_A'],
#       dtype='object')

# %%
wesee['tryColumnForInvestment'].value_counts().head(10).plot(kind='bar')
plt.title('Updated Investment Distribution')
# Out:
# Text(0.5, 1.0, 'Updated Investment Distribution')

# %%
fig = plt.figure(figsize=(10,10))

plt.subplot(2,2,1)
wesee['tryColumnForInvestment'].value_counts().head(10).plot(kind='bar')
plt.title('Updated Investment Distribution')

plt.subplot(2,2,2)
wesee['InvestmentnType'].value_counts().head(10).plot(kind='bar')
plt.title('Previous Investment Distribution')

plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fig = plt.figure(figsize=(10,10))

plt.subplot(2,2,1)
angelist['stage'].value_counts().head(10).plot(kind='bar')
plt.title('Updated Investment Distribution')


plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
wesee['Reached_Series_A'] = (wesee['tryColumnForInvestment']=="Series A") | (wesee['Amount in USD'].between(1250000,7000000))

# %%
wesee["Reached_Series_A"].value_counts()
# Out:
# False    1497
# True      573
# Name: Reached_Series_A, dtype: int64

# %% [markdown]
# ### wesee.to_excel('FinalFinalFinalSheet.xlsx')

# %% [markdown]
# # Adding years column to the dataframe

# %%
import datetime

x = datetime.datetime(2020, 5, 1)

print(x)
# Out:
# 2020-05-01 00:00:00

# %%
m={'Jan':1,'Feb':2,'Mar':3,'Apr':4,'May':5,'Jun':6,'Jul':7,'Aug':8,'Sep':9,'Oct':10,'Nov':11,'Dec':12}
def clean_date(curr_date):
    mo,year = (curr_date.split(' ’'))
    return(datetime.datetime(int('20'+year), m[mo], 1))

# %%
clean_date('Jun ’10')
# Out:
# datetime.datetime(2010, 6, 1, 0, 0)

# %%
def year_estd(date):
    now = datetime.datetime(2022,8,14,0,0,0,0)
    diff = now - date
    return (diff.days/365)

# %%
year_estd(clean_date('Dec ’15'))
# Out:
# 6.706849315068493

# %%
year_estd(wesee['Date dd/mm/yyyy'][1])
# Out:
# 2.5863013698630137

# %%
wesee['Date dd/mm/yyyy'][1]
# Out:
# Timestamp('2020-01-13 00:00:00')

# %%
wesee.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'Unnamed: 0.1.1', 'Sr No',
#        'Date dd/mm/yyyy', 'Startup Name', 'Industry Vertical', 'SubVertical',
#        'City  Location', 'Investors Name', 'InvestmentnType', 'Amount in USD',
#        'TierBoolean', 'AmountInUSDBoolean', 'Year', 'Month',
#        'OnlineMarketPlaceBoolean', 'EducationBool', 'ServiceInternetBoolean',
#        'HealthTechBoolean', 'Quantile Rank', 'Number_Investors',
#        'tryColumnForInvestment', 'Reached_Series_A'],
#       dtype='object')

# %%
wesee.drop('Unnamed: 0.1',axis=1,inplace =True)

# %%
wesee['Date dd/mm/yyyy'] = wesee['Date dd/mm/yyyy'].apply(lambda row: year_estd(row))

# %%
wesee
# Out:
#       Unnamed: 0  Unnamed: 0.1.1  Sr No  Date dd/mm/yyyy  \
# 0              0               0      1         2.597260
# 1              1               1      2         2.586301
# 2              2               2      3         2.597260
# 3              3               3      4         2.616438
# 4              4               4      5         2.616438
# ...          ...             ...    ...              ...
# 2065        2065            2065   3039         7.547945
# 2066        2066            2066   3040         7.545205
# 2067        2067            2067   3041         7.545205
# 2068        2068            2068   3042         7.542466
# 2069        2069            2069   3044         7.539726
#
#                       Startup Name    Industry Vertical  \
# 0                           BYJU’S               Edtech
# 1                           Shuttl       Transportation
# 2                        Mamaearth            eCommerce
# ...

# %%
wesee['City  Location'].unique()
# Out:
# array(['Bengaluru', 'Gurgaon', 'New Delhi', 'Mumbai', 'Chennai', 'Pune',
#        'Noida', 'Faridabad', 'San Francisco', 'San Jose,', 'Amritsar',
#        'Delhi', 'Kormangala', 'Tulangan', 'Hyderabad', 'Burnsville',
#        'Menlo Park', 'Gurugram', 'Palo Alto', 'Santa Monica', 'Singapore',
#        'Taramani', 'Andheri', 'Chembur', 'Haryana', 'New York',
#        'Karnataka', 'Mumbai/Bengaluru', 'Bhopal',
#        'Bengaluru and Gurugram', 'India/Singapore', 'Jaipur', 'India/US',
#        'Nagpur', 'Indore', 'New York, Bengaluru', 'California', 'India',
#        'Ahemadabad', 'Rourkela', 'Bhubneswar', 'Chandigarh',
#        'Delhi & Cambridge', 'Kolkata', 'Coimbatore', 'Udaipur',
#        'Ahmedabad', 'Surat', 'Goa', 'Gaya', 'Vadodara', 'Missourie',
#        'Panaji', 'Gwalior', 'Bengaluru/ Bangkok', 'Kerala', nan,
#        'Lucknow', 'Trivandrum', 'SFO / Bengaluru', 'Pune/Seattle',
#        'Pune / Dubai', 'Bengaluru/ SFO', 'Varanasi', 'New Delhi / US',
# ...

# %%
angelist['location'].nunique()
# Out:
# 533

# %%
wesee['InvestmentnType'].value_counts().head(10)
# Out:
# Private Equity          1072
# Seed Funding             747
# Seed Angel Funding       104
# Debt Funding              24
# Series A                  22
# Series B                  20
# Series C                  14
# Series D                  12
# Private Equity Round       4
# Pre-Series A               4
# Name: InvestmentnType, dtype: int64

# %%
wesee.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1.1', 'Sr No', 'Date dd/mm/yyyy',
#        'Startup Name', 'Industry Vertical', 'SubVertical', 'City  Location',
#        'Investors Name', 'InvestmentnType', 'Amount in USD', 'TierBoolean',
#        'AmountInUSDBoolean', 'Year', 'Month', 'OnlineMarketPlaceBoolean',
#        'EducationBool', 'ServiceInternetBoolean', 'HealthTechBoolean',
#        'Quantile Rank', 'Number_Investors', 'tryColumnForInvestment',
#        'Reached_Series_A'],
#       dtype='object')

# %%
wesee['Industry Vertical'].value_counts().head(10).plot(kind="bar")

plt.title("Top 10 Verticals")
plt.xlabel("Industry")
plt.ylabel("Frequencies")
# Out:
# Text(0, 0.5, 'Frequencies')

# %%
wesee[wesee["InvestmentnType"]=='Pre-series A']
# Out:
#    Unnamed: 0  Unnamed: 0.1.1  Sr No  Date dd/mm/yyyy  \
# 3           3               3      4         2.616438
#
#                    Startup Name Industry Vertical        SubVertical  \
# 3  https://www.wealthbucket.in/           FinTech  Online Investment
#
#   City  Location  Investors Name InvestmentnType  ...  Year  Month  \
# 3      New Delhi  Vinod Khatumal    Pre-series A  ...  2020      1
#
#    OnlineMarketPlaceBoolean  EducationBool  ServiceInternetBoolean  \
# 3                     False          False                   False
#
#    HealthTechBoolean  Quantile Rank  Number_Investors  tryColumnForInvestment  \
# 3              False              5                 1            Pre-series A
#
#    Reached_Series_A
# 3              True
#
# [1 rows x 23 columns]

# %%
wesee['']
# Out:
#       Unnamed: 0  Unnamed: 0.1.1  Sr No  Date dd/mm/yyyy  \
# 0              0               0      1         2.597260
# 1              1               1      2         2.586301
# 2              2               2      3         2.597260
# 3              3               3      4         2.616438
# 4              4               4      5         2.616438
# ...          ...             ...    ...              ...
# 2065        2065            2065   3039         7.547945
# 2066        2066            2066   3040         7.545205
# 2067        2067            2067   3041         7.545205
# 2068        2068            2068   3042         7.542466
# 2069        2069            2069   3044         7.539726
#
#                       Startup Name    Industry Vertical  \
# 0                           BYJU’S               Edtech
# 1                           Shuttl       Transportation
# 2                        Mamaearth            eCommerce
# ...

# %%
wesee['InvestmentnType'].value_counts()
# Out:
# Private Equity                 1072
# Seed Funding                    747
# Seed Angel Funding              104
# Debt Funding                     24
# Series A                         22
# Series B                         20
# Series C                         14
# Series D                         12
# Private Equity Round              4
# Pre-Series A                      4
# Angel   Seed Funding              4
# Seed                              4
# Venture Round                     2
# Seed  Angel Funding               2
# pre-Series A                      2
# Series F                          2
# Equity                            2
# Series E                          2
# Private Funding                   1
# Equity Based Funding              1
# Term Loan                         1
# Private                           1
# Series B (Extension)              1
# Mezzanine                         1
# Structured Debt                   1
# Debt-Funding                      1
# ...

# %%
wesee.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1.1', 'Sr No', 'Date dd/mm/yyyy',
#        'Startup Name', 'Industry Vertical', 'SubVertical', 'City  Location',
#        'Investors Name', 'InvestmentnType', 'Amount in USD', 'TierBoolean',
#        'AmountInUSDBoolean', 'Year', 'Month', 'OnlineMarketPlaceBoolean',
#        'EducationBool', 'ServiceInternetBoolean', 'HealthTechBoolean',
#        'Quantile Rank', 'Number_Investors', 'tryColumnForInvestment',
#        'Reached_Series_A'],
#       dtype='object')

# %%
wesee[wesee['tryColumnForInvestment']=="Pre-series A"]["City  Location"].value_counts().head(10).plot(kind='bar')

plt.title("Top Locations(Pre-Series A)")
plt.xlabel("Location")
plt.ylabel("Frequencies")
# Out:
# Text(0, 0.5, 'Frequencies')

# %%
wesee['tryColumnForInvestment'].value_counts().head(10).plot(kind="bar")

plt.title("Top Funding Type")
plt.xlabel("types")
plt.ylabel("Frequencies")
# Out:
# Text(0, 0.5, 'Frequencies')

# %%
q1df = wesee[wesee['Month']<4]
q2df = wesee[(wesee['Month']>3) & (wesee['Month']<7)]
q3df = wesee[(wesee['Month']>6) & (wesee['Month']<10)]
q4df = wesee[wesee['Month']>9]

# %%
q1IV = q1df['Industry Vertical'].value_counts().head(10)
q2IV = q2df['Industry Vertical'].value_counts().head(10)
q3IV = q3df['Industry Vertical'].value_counts().head(10)
q4IV = q4df['Industry Vertical'].value_counts().head(10)


fig = plt.figure(figsize=(10,10))

plt.subplot(2, 2, 1)
q1IV.plot(kind='bar')
plt.title("Q1")
plt.xlabel("Industries")
plt.ylabel("Frequencies")


plt.subplot(2, 2, 2)
q2IV.plot(kind='bar')
plt.title("Q2")
plt.xlabel("Industries")
plt.ylabel("Frequencies")

plt.subplot(2, 2, 3)
q3IV.plot(kind='bar')
plt.title("Q3")
plt.xlabel("Industries")
plt.ylabel("Frequencies")


plt.subplot(2, 2, 4)
q4IV.plot(kind='bar')
plt.title("Q4")
plt.xlabel("Industries")
plt.ylabel("Frequencies")


plt.tight_layout()
plt.show()

# %%
wesee.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1.1', 'Sr No', 'Date dd/mm/yyyy',
#        'Startup Name', 'Industry Vertical', 'SubVertical', 'City  Location',
#        'Investors Name', 'InvestmentnType', 'Amount in USD', 'TierBoolean',
#        'AmountInUSDBoolean', 'Year', 'Month', 'OnlineMarketPlaceBoolean',
#        'EducationBool', 'ServiceInternetBoolean', 'HealthTechBoolean',
#        'Quantile Rank', 'Number_Investors', 'tryColumnForInvestment',
#        'Reached_Series_A'],
#       dtype='object')

# %%
wesee['Number_Investors'].value_counts().plot(kind='bar')

plt.title("Investors Distribution")
plt.xlabel("Number")
plt.ylabel("Frequencies")
# Out:
# Text(0, 0.5, 'Frequencies')

# %%
wesee[wesee['tryColumnForInvestment']=="Series A"]['Number_Investors'].value_counts().plot(kind='bar')

plt.title("Investors Distribution (Series A)")
plt.xlabel("Number")
plt.ylabel("Frequencies")
# Out:
# Text(0, 0.5, 'Frequencies')
