# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
from matplotlib.pyplot import figure

# %%
from collections import Counter
import chart_studio
import chart_studio.plotly as py
import plotly.express as px
from pprint import pprint

# %%
BigDF = pd.read_excel(r"C:\Users\ayush\Desktop\Hubli Project\InvestmentModel\CorrectData\Megasheet(no Date).xlsx")

# %%
BigDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2070 entries, 0 to 2069
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          2070 non-null   int64
#  1   Unnamed: 0.1        2070 non-null   int64
#  2   Sr No               2070 non-null   int64
#  3   Date dd/mm/yyyy     2070 non-null   datetime64[ns]
#  4   Startup Name        2070 non-null   object
#  5   Industry Vertical   1939 non-null   object
#  6   SubVertical         1416 non-null   object
#  7   City  Location      1935 non-null   object
#  8   Investors Name      2050 non-null   object
#  9   InvestmentnType     2069 non-null   object
#  10  Amount in USD       2070 non-null   int64
#  11  TierBoolean         2070 non-null   bool
#  12  AmountInUSDBoolean  2070 non-null   bool
# dtypes: bool(2), datetime64[ns](1), int64(4), object(6)
# memory usage: 182.1+ KB

# %%
BigDF.head(5)
# Out:
#    Unnamed: 0  Unnamed: 0.1  Sr No Date dd/mm/yyyy  \
# 0           0             0      1      2020-01-09
# 1           1             1      2      2020-01-13
# 2           2             2      3      2020-01-09
# 3           3             3      4      2020-01-02
# 4           4             4      5      2020-01-02
#
#                    Startup Name    Industry Vertical  \
# 0                        BYJU’S               E-Tech
# 1                        Shuttl       Transportation
# 2                     Mamaearth            eCommerce
# 3  https://www.wealthbucket.in/              FinTech
# 4                        Fashor  Fashion and Apparel
#
#                              SubVertical City  Location  \
# 0                             E-learning      Bengaluru
# 1              App based shuttle service        Gurgaon
# 2  Retailer of baby and toddler products      Bengaluru
# 3                      Online Investment      New Delhi
# ...

# %%
BigDF['Year'] = BigDF['Date dd/mm/yyyy'].dt.year
BigDF['Month'] = BigDF['Date dd/mm/yyyy'].dt.month

# %%
BigDF.to_excel('BigDF.xlsx')

# %%
BigDF.head(5)
# Out:
#    Unnamed: 0  Unnamed: 0.1  Sr No Date dd/mm/yyyy  \
# 0           0             0      1      2020-01-09
# 1           1             1      2      2020-01-13
# 2           2             2      3      2020-01-09
# 3           3             3      4      2020-01-02
# 4           4             4      5      2020-01-02
#
#                    Startup Name    Industry Vertical  \
# 0                        BYJU’S               E-Tech
# 1                        Shuttl       Transportation
# 2                     Mamaearth            eCommerce
# 3  https://www.wealthbucket.in/              FinTech
# 4                        Fashor  Fashion and Apparel
#
#                              SubVertical City  Location  \
# 0                             E-learning      Bengaluru
# 1              App based shuttle service        Gurgaon
# 2  Retailer of baby and toddler products      Bengaluru
# 3                      Online Investment      New Delhi
# ...

# %%
# Top Startups 

BigDF.sort_values(["Amount in USD"],ascending=False)[1:20][['Startup Name','Amount in USD']].set_index("Startup Name").plot(kind='bar')
plt.title("Top startups")
plt.xlabel("Startup name")
plt.ylabel("Total raised (10 Millions ($))")

plt.show()

# %%
BigDF = BigDF.drop(['Unnamed: 0','Unnamed: 0.1'],axis = 1)
BigDF.head(10)
# Out:
#    Sr No Date dd/mm/yyyy                  Startup Name    Industry Vertical  \
# 0      1      2020-01-09                        BYJU’S               E-Tech
# 1      2      2020-01-13                        Shuttl       Transportation
# 2      3      2020-01-09                     Mamaearth            eCommerce
# 3      4      2020-01-02  https://www.wealthbucket.in/              FinTech
# 4      5      2020-01-02                        Fashor  Fashion and Apparel
# 5      6      2020-01-13                         Pando            Logistics
# 6      7      2020-01-10                        Zomato          Hospitality
# 7      8      2019-12-12                        Ecozen           Technology
# 8      9      2019-12-06                      CarDekho            eCommerce
# 9     10      2019-12-03                  Dhruva Space            Aerospace
#
#                                 SubVertical City  Location  \
# 0                                E-learning      Bengaluru
# ...

# %%
BigDF['InvestmentnType'].value_counts().head(10).plot(kind='bar')

plt.rcParams["figure.figsize"] = [7.00, 5.50]
plt.rcParams["figure.autolayout"] = True


plt.title("Investment Type Chart")
plt.xlabel("Startup Stage")
plt.ylabel("Frequencies")
plt.figure(figsize = (20,10))
plt.show()

# %%
BigDF['Industry Vertical'].value_counts().head(30)
# Out:
# Consumer Internet                589
# Technology                       310
# eCommerce                        201
# Finance                           57
# Healthcare                        44
# Logistics                         23
# Education                         19
# Food & Beverage                   15
# Ed-Tech                           12
# FinTech                            9
# IT                                 8
# Fin-Tech                           6
# Food and Beverage                  5
# Online Food Delivery               5
# Health and Wellness                5
# Others                             4
# Logistics Tech                     4
# EdTech                             4
# Transportation                     4
# Social Media                       3
# Information Technology             3
# Transport                          3
# Automobile                         3
# Online Education Platform          3
# Big Data & Analytics platform      3
# ...

# %%
BigDF['Industry Vertical'].value_counts().head(10).plot(kind='bar')


plt.title("Industry Verticals")
plt.xlabel("Industries")
plt.ylabel("Frequencies")
plt.figure(figsize = (20,10))
plt.show()

# %% [markdown]
# # <span style="color:blue">*Consumer Internet includes*</span>
#
# ### - providing online services for already existing markets
#         - Uber
#         - amazon
#         - booking.com
#         - ebay
#         - peleton
#         - paytm
#         - Google India
#         - Zomato

# %%
BigDF[BigDF['InvestmentnType']=='Seed Funding']['City  Location'].value_counts()[:15].plot(kind='bar')
plt.title("Seed Location (Top 15)")
plt.xlabel("Industry")
plt.ylabel("Frequencies")

plt.show()

# %%
BigDF[BigDF['InvestmentnType']=='Seed Funding']['Industry Vertical'].value_counts()[:15].plot(kind='bar')
plt.title("Seed Funding (Top 15)")
plt.xlabel("Industry")
plt.ylabel("Frequencies")

plt.show()

# %%
BigDF[BigDF['InvestmentnType']=='Private Equity']['Industry Vertical'].value_counts()[:15].plot(kind='bar')
plt.title("Private Equity (Top 15)")
plt.xlabel("Industry")
plt.ylabel("Frequencies")

plt.show()

# %%
BigDF[BigDF['InvestmentnType']=='Private Equity']['City  Location'].value_counts()[:15].plot(kind='bar')
plt.title("Private Equity Location (Top 15)")
plt.xlabel("Industry")
plt.ylabel("Frequencies")

plt.show()

# %%
BigDF.head()
# Out:
#    Sr No Date dd/mm/yyyy                  Startup Name    Industry Vertical  \
# 0      1      2020-01-09                        BYJU’S               E-Tech
# 1      2      2020-01-13                        Shuttl       Transportation
# 2      3      2020-01-09                     Mamaearth            eCommerce
# 3      4      2020-01-02  https://www.wealthbucket.in/              FinTech
# 4      5      2020-01-02                        Fashor  Fashion and Apparel
#
#                              SubVertical City  Location  \
# 0                             E-learning      Bengaluru
# 1              App based shuttle service        Gurgaon
# 2  Retailer of baby and toddler products      Bengaluru
# 3                      Online Investment      New Delhi
# 4            Embroiled Clothes For Women         Mumbai
#
#               Investors Name       InvestmentnType  Amount in USD  \
# 0    Tiger Global Management  Private Equity Round      200000000
# ...

# %%
BigDF[BigDF['City  Location']=='Bengaluru']['InvestmentnType'].value_counts()[:5].plot(kind='bar')
plt.title("Bengaluru funding distribution(Top 5)")
plt.xlabel("Investment Type")
plt.ylabel("Frequencies")

plt.show()

# %%
BigDF[BigDF['City  Location']=='Mumbai']['InvestmentnType'].value_counts()[:5].plot(kind='bar')
plt.title("Mumbai funding distribution(Top 5)")
plt.xlabel("Investment Type")
plt.ylabel("Frequencies")

plt.show()

# %%
BigDF[BigDF['City  Location']=='New Delhi']['InvestmentnType'].value_counts()[:5].plot(kind='bar')
plt.title("New Delhi funding distribution(Top 5)")
plt.xlabel("Investment Type")
plt.ylabel("Frequencies")

plt.show()

# %%
BigDF[BigDF['City  Location']=='Chennai']['InvestmentnType'].value_counts()[:5].plot(kind='bar')
plt.title("Chennai funding distribution(Top 5)")
plt.xlabel("Investment Type")
plt.ylabel("Frequencies")

plt.show()

# %%
BigDF[BigDF['City  Location']=='Kolkata']['InvestmentnType'].value_counts()[:5].plot(kind='bar')
plt.title("kolkata funding distribution(Top 5)")
plt.xlabel("Investment Type")
plt.ylabel("Frequencies")

plt.show()

# %%
BigDF[BigDF['City  Location']=='New Delhi']['Industry Vertical'].value_counts()[:10].plot(kind='bar')
plt.title("New Delhi Industry distribution(Top 10)")
plt.xlabel("Industries")
plt.ylabel("Frequencies")

plt.show()

# %%
BigDF[BigDF['City  Location']=='Mumbai']['Industry Vertical'].value_counts()[:10].plot(kind='bar')
plt.title("Mumbai Industry distribution(Top 10)")
plt.xlabel("Industries")
plt.ylabel("Frequencies")

plt.show()

# %%
BigDF[BigDF['City  Location']=='Bengaluru']['Industry Vertical'].value_counts()[:10].plot(kind='bar')
plt.title("Bengaluru Industry distribution(Top 10)")
plt.xlabel("Industries")
plt.ylabel("Frequencies")

plt.show()

# %%
BigDF
# Out:
# Index(['Sr No', 'Date dd/mm/yyyy', 'Startup Name', 'Industry Vertical',
#        'SubVertical', 'City  Location', 'Investors Name', 'InvestmentnType',
#        'Amount in USD', 'TierBoolean', 'AmountInUSDBoolean', 'Year', 'Month'],
#       dtype='object')

# %%
sns.countplot(x=)
# Out:
# <AxesSubplot:>

# %%
q = df["Month"].value_counts().sort_index()

# %%
q.plot(kind='bar')
plt.title("Month vs Startups")
plt.xlabel("Months")
plt.ylabel("Frequency")

plt.show()

# %%
q4df = df[df['Month']>9]

# %%
q1df = df[df['Month']<4]

# %%
q2df = df[(df['Month']>3) & (df['Month']<7)]

# %%
q3df = df[(df['Month']>6) & (df['Month']<10)]

# %% [markdown]
# # Quarter wise analysis

# %%
q1IV = q1df['Industry Vertical'].value_counts().head(10)
q1IV.plot(kind='bar')


plt.title("Industry Verticals Q1")
plt.xlabel("Industries")
plt.ylabel("Frequencies")
plt.figure(figsize = (20,10))
plt.show()

q2IV = q2df['Industry Vertical'].value_counts().head(10)
q2IV.plot(kind='bar')

plt.title("Industry Verticals Q2")
plt.xlabel("Industries")
plt.ylabel("Frequencies")
plt.figure(figsize = (20,10))
plt.show()

q3IV = q3df['Industry Vertical'].value_counts().head(10)
q3IV.plot(kind='bar')

plt.title("Industry Verticals Q3")
plt.xlabel("Industries")
plt.ylabel("Frequencies")
plt.figure(figsize = (20,10))
plt.show()

q4IV = q4df['Industry Vertical'].value_counts().head(10)
q4IV.plot(kind='bar')


plt.title("Industry Verticals Q4")
plt.xlabel("Industries")
plt.ylabel("Frequencies")
plt.figure(figsize = (20,10))
plt.show()

# %% [markdown]
# # Quarter wise Industry

# %%
fig = plt.figure(figsize=(10,10))

plt.subplot(2, 2, 1)
q1IV.plot(kind='bar')
plt.title("Q1")
plt.xlabel("Industries")
plt.ylabel("Frequencies")


plt.subplot(2, 2, 2)
q2IV.plot(kind='bar')
plt.title("Q2")
plt.xlabel("Industries")
plt.ylabel("Frequencies")

plt.subplot(2, 2, 3)
q3IV.plot(kind='bar')
plt.title("Q3")
plt.xlabel("Industries")
plt.ylabel("Frequencies")


plt.subplot(2, 2, 4)
q4IV.plot(kind='bar')
plt.title("Q4")
plt.xlabel("Industries")
plt.ylabel("Frequencies")



plt.show()

# %% [markdown]
# # Quarter wise Location

# %%
q1LC = q1df['City  Location'].value_counts().head(10)
q2LC = q2df['City  Location'].value_counts().head(10)
q3LC = q3df['City  Location'].value_counts().head(10)
q4LC = q4df['City  Location'].value_counts().head(10)

# %%
fig = plt.figure(figsize=(10,10))

plt.subplot(2, 2, 1)
q1LC.plot(kind='bar')
plt.title("Q1")
plt.xlabel("Location")
plt.ylabel("Frequencies")


plt.subplot(2, 2, 2)
q2LC.plot(kind='bar')
plt.title("Q2")
plt.xlabel("Location")
plt.ylabel("Frequencies")

plt.subplot(2, 2, 3)
q3LC.plot(kind='bar')
plt.title("Q3")
plt.xlabel("Location")
plt.ylabel("Frequencies")


plt.subplot(2, 2, 4)
q4LC.plot(kind='bar')
plt.title("Q4")
plt.xlabel("Location")
plt.ylabel("Frequencies")



plt.show()

# %% [markdown]
# # City Verticals

# %%
q1D=q1df[q1df['City  Location']=="New Delhi"]['Industry Vertical'].value_counts().head(10)
q2D=q2df[q2df['City  Location']=="New Delhi"]['Industry Vertical'].value_counts().head(10)
q3D=q3df[q3df['City  Location']=="New Delhi"]['Industry Vertical'].value_counts().head(10)
q4D=q4df[q4df['City  Location']=="New Delhi"]['Industry Vertical'].value_counts().head(10)

# %%
q1B=q1df[q1df['City  Location']=="Bengaluru"]['Industry Vertical'].value_counts().head(10)
q2B=q2df[q2df['City  Location']=="Bengaluru"]['Industry Vertical'].value_counts().head(10)
q3B=q3df[q3df['City  Location']=="Bengaluru"]['Industry Vertical'].value_counts().head(10)
q4B=q4df[q4df['City  Location']=="Bengaluru"]['Industry Vertical'].value_counts().head(10)

# %%
q1M=q1df[q1df['City  Location']=="Mumbai"]['Industry Vertical'].value_counts().head(10)
q2M=q2df[q2df['City  Location']=="Mumbai"]['Industry Vertical'].value_counts().head(10)
q3M=q3df[q3df['City  Location']=="Mumbai"]['Industry Vertical'].value_counts().head(10)
q4M=q4df[q4df['City  Location']=="Mumbai"]['Industry Vertical'].value_counts().head(10)

# %% [markdown]
# ## Delhi QUARTERWISE INDUSTRY

# %%
fig = plt.figure(figsize=(10,15))
plt.title("NEW DELHI QUARTERWISE INDUSTRY")

plt.subplot(2, 2, 1)
q1D.plot(kind='bar')
plt.title("Q1")
plt.xlabel("Industry")
plt.ylabel("Frequencies")


plt.subplot(2, 2, 2)
q2D.plot(kind='bar')
plt.title("Q2")
plt.xlabel("Industry")
plt.ylabel("Frequencies")

plt.subplot(2, 2, 3)
q3D.plot(kind='bar')
plt.title("Q3")
plt.xlabel("Industry")
plt.ylabel("Frequencies")


plt.subplot(2, 2, 4)
q4D.plot(kind='bar')
plt.title("Q4")
plt.xlabel("Industry")
plt.ylabel("Frequencies")



plt.show()

# %% [markdown]
# # Bangalore Quarterwise Industry

# %%
fig = plt.figure(figsize=(10,15))
plt.title("BENGALURU QUARTERWISE INDUSTRY")

plt.subplot(2, 2, 1)
q1B.plot(kind='bar')
plt.title("Q1")
plt.xlabel("Industry")
plt.ylabel("Frequencies")


plt.subplot(2, 2, 2)
q2B.plot(kind='bar')
plt.title("Q2")
plt.xlabel("Industry")
plt.ylabel("Frequencies")

plt.subplot(2, 2, 3)
q3B.plot(kind='bar')
plt.title("Q3")
plt.xlabel("Industry")
plt.ylabel("Frequencies")


plt.subplot(2, 2, 4)
q4B.plot(kind='bar')
plt.title("Q4")
plt.xlabel("Industry")
plt.ylabel("Frequencies")



plt.show()

# %% [markdown]
# # Mumbai Quarterwise Industry

# %%
fig = plt.figure(figsize=(10,15))
plt.title("MUMBAI QUARTERWISE INDUSTRY")

plt.subplot(2, 2, 1)
q1M.plot(kind='bar')
plt.title("Q1")
plt.xlabel("Industry")
plt.ylabel("Frequencies")


plt.subplot(2, 2, 2)
q2M.plot(kind='bar')
plt.title("Q2")
plt.xlabel("Industry")
plt.ylabel("Frequencies")

plt.subplot(2, 2, 3)
q3M.plot(kind='bar')
plt.title("Q3")
plt.xlabel("Industry")
plt.ylabel("Frequencies")


plt.subplot(2, 2, 4)
q4M.plot(kind='bar')
plt.title("Q4")
plt.xlabel("Industry")
plt.ylabel("Frequencies")



plt.show()

# %% [markdown]
# # Repeated funding

# %%
df.columns
# Out:
# Index(['Sr No', 'Date dd/mm/yyyy', 'Startup Name', 'Industry Vertical',
#        'SubVertical', 'City  Location', 'Investors Name', 'InvestmentnType',
#        'Amount in USD', 'TierBoolean', 'AmountInUSDBoolean', 'Year', 'Month'],
#       dtype='object')

# %%
df["Startup Name"].value_counts().head(25)
# Out:
# Swiggy           8
# Ola Cabs         7
# Grofers          5
# UrbanClap        5
# Toppr            5
# Paytm            5
# Flipkart         5
# Medinfi          5
# Capital Float    5
# Nykaa            5
# Rivigo           4
# Zomato           4
# Ola              4
# Unacademy        4
# Jugnoo           4
# Udaan            4
# Magicpin         4
# Voonik           4
# Icertis          4
# Aye Finance      4
# Shuttl           4
# Furlenco         4
# NoBroker         4
# Meesho           4
# Uniphore         4
# Name: Startup Name, dtype: int64

# %%
rdf = df.drop_duplicates(subset=['Startup Name'],keep='first')

# %%
rdf["Startup Name"].value_counts()
# Out:
# BYJU’S              1
# TableHero           1
# GoYaNo              1
# Snapdeal            1
# Aasaanjobs          1
#                    ..
# Ace Turtle          1
# MyGreens            1
# YepMe               1
# Balance App         1
# couponmachine.in    1
# Name: Startup Name, Length: 1702, dtype: int64

# %%
fig = plt.figure(figsize=(10,15))

plt.subplot(2, 2, 1)

rdf[rdf['City  Location']=='Bengaluru']['Industry Vertical'].value_counts()[:10].plot(kind='bar')
plt.title("Bengaluru Industry distribution after removing repeaters(Top 10)")
plt.xlabel("Industries")
plt.ylabel("Frequencies")


plt.subplot(2, 2, 2)

BigDF[BigDF['City  Location']=='Bengaluru']['Industry Vertical'].value_counts()[:10].plot(kind='bar')
plt.title("Bengaluru Industry distribution(Top 10)")
plt.xlabel("Industries")
plt.ylabel("Frequencies")

plt.show()

# %%
fig = plt.figure(figsize=(10,15))

plt.subplot(2, 2, 1)

rdf[rdf['City  Location']=='New Delhi']['Industry Vertical'].value_counts()[:10].plot(kind='bar')
plt.title("New Delhi Industry distribution after removing repeaters(Top 10)")
plt.xlabel("Industries")
plt.ylabel("Frequencies")


plt.subplot(2, 2, 2)

BigDF[BigDF['City  Location']=='New Delhi']['Industry Vertical'].value_counts()[:10].plot(kind='bar')
plt.title("New Delhi Industry distribution(Top 10)")
plt.xlabel("Industries")
plt.ylabel("Frequencies")

plt.show()

# %% [markdown]
# # Comparing and Contrasting with Smaller testing Dataset

# %%
# creating Smaller Dataset

# %%
SmallDF = df[df['AmountInUSDBoolean']==True]

# %%
SmallDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 352 entries, 60 to 2069
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Sr No               352 non-null    int64
#  1   Date dd/mm/yyyy     352 non-null    datetime64[ns]
#  2   Startup Name        352 non-null    object
#  3   Industry Vertical   317 non-null    object
#  4   SubVertical         228 non-null    object
#  5   City  Location      315 non-null    object
#  6   Investors Name      347 non-null    object
#  7   InvestmentnType     352 non-null    object
#  8   Amount in USD       352 non-null    int64
#  9   TierBoolean         352 non-null    bool
#  10  AmountInUSDBoolean  352 non-null    bool
#  11  Year                352 non-null    int64
#  12  Month               352 non-null    int64
# dtypes: bool(2), datetime64[ns](1), int64(4), object(6)
# memory usage: 33.7+ KB
